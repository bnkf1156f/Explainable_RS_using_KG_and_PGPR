# %% [markdown]
# # Explainable Recommender System with Knowledge Graphs
#
# **Name: Virkha Kumari**<br>
# **RS Project**
# <br>

# %% [markdown]
# **Code with explanation:** https://explainablerecsys.github.io/recsys2022/
# <BR><br>
# **TUTORIAL**:
# https://www.youtube.com/watch?v=qPiIvcCOyBg
# <br><br>
# **Folder containing all files**
# https://drive.google.com/drive/folders/1FBnh8SJvdTgmJoUoMvrzg7BppiHO8oIc
# <br><br>
# **Datasets=>** ***MovieLens-1M*** = 1 million user-movie ratings (0-5) from 6000 users on 4000 movies.

# %% [markdown]
# ## Datasets, KGs, and pre-processing

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# LOAD MOVIELENS DATA
ml1m_path='data/ml1m'
ml1m_users_df=pd.read_csv(f'{ml1m_path}/users.dat', sep='::', names=["UserID","Gender","Age","Occupation","Zip-code"], header=None)
display(ml1m_users_df.head(5))
print(f'Unique Users: {len(ml1m_users_df)}')

ml1m_movies_df=pd.read_csv(f'{ml1m_path}/movies.dat', sep='::', names=["movie_id", "movie_name", "genre"], header=None, encoding='latin-1')
display(ml1m_movies_df.head(5))
print(f'Unique Videos: {len(ml1m_movies_df)}')

ml1m_ratings_df=pd.read_csv(f'{ml1m_path}/ratings.dat', sep="::", names=["user_id", "movie_id", "rating", "timestamp"], header=None)
display(ml1m_ratings_df.head(5))
print(f"Unique interactions: {len(ml1m_ratings_df)}")
# Out:
#    UserID Gender  Age  Occupation Zip-code
# 0       1      F    1          10    48067
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7    02460
# 4       5      M   25          20    55455
# Unique Users: 6040
#    movie_id                          movie_name                         genre
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# Unique Videos: 3883
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291
# Unique interactions: 1000209

# %% [markdown]
# **From the entity url, you can access the page of the entity in the DBpedia knowledge base and read more about it and what are the relations that it has with other entities.**

# %%
# LOAD DBPEDIA Knowledge Graph (KG) data for MovieLens
entities_df=pd.read_csv(f'{ml1m_path}/kg/e_map.dat', sep="\t", names=["entity_id", "entity_url"])
display(entities_df.head(5))

movies_to_kg_df=pd.read_csv(f'{ml1m_path}/kg/i2kg_map.tsv', sep="\t", names=["dataset_id", "movie_name", "entity_url"])
display(movies_to_kg_df.head(5))
print(f"Items mapped in the KG: {movies_to_kg_df.shape[0]}")

kg_df=pd.read_csv(f'{ml1m_path}/kg/kg.dat', sep="\t")
display(kg_df.head(5))
print(f"Number of triplets: {kg_df.shape[0]}")

relations_df=pd.read_csv(f'{ml1m_path}/kg/r_map.dat', sep="\t", names=["relation_id", "relation_url"])
display(relations_df.head(5))
# Out:
#    entity_id                                         entity_url
# 0          0            http://dbpedia.org/resource/Roger_Carel
# 1          1       http://dbpedia.org/resource/Soundtrack_album
# 2          2           http://dbpedia.org/resource/1982_in_film
# 3          3  http://dbpedia.org/resource/Category:Films_set...
# 4          4            http://dbpedia.org/resource/Plaza_Hotel
#    dataset_id                movie_name  \
# 0         781    Stealing Beauty (1996)
# 1        1799      Suicide Kings (1997)
# 2         521  Romeo Is Bleeding (1993)
# 3        3596            Screwed (2000)
# 4        3682       Magnum Force (1973)
#
#                                         entity_url
# 0      http://dbpedia.org/resource/Stealing_Beauty
# 1        http://dbpedia.org/resource/Suicide_Kings
# 2    http://dbpedia.org/resource/Romeo_Is_Bleeding
# 3  http://dbpedia.org/resource/Screwed_(2000_film)
# 4         http://dbpedia.org/resource/Magnum_Force
# Items mapped in the KG: 3301
#    entity_head  entity_tail  relation
# 0         9386         4955        12
# 1         6851         1770         1
# 2          210         5210         8
# 3         4205          406        12
# 4        11533        12345         3
# Number of triplets: 434189
#    relation_id                                     relation_url
# 0            0       http://dbpedia.org/ontology/cinematography
# 1            1  http://dbpedia.org/property/productionCompanies
# 2            2             http://dbpedia.org/property/composer
# 3            3                 http://purl.org/dc/terms/subject
# 4            4          http://dbpedia.org/ontology/openingFilm

# %%
# Solve the problem: linking process fails and we end up having some products not mapped with the KG
# So we will solve "MISSING ITEM IN KG" problem
print(f'Items in original dataset: {ml1m_movies_df.shape[0]}')
print(f'Items correctly mapped in KG: {movies_to_kg_df.shape[0]}')

# Let's remove from the ml1m_movies_df DataFrame the movies that are not in item_to_kg_map.
num_movies=ml1m_movies_df.shape[0]
ml1m_movies_df=ml1m_movies_df[ml1m_movies_df['movie_id'].isin(movies_to_kg_df.dataset_id)]
ml1m_movies_df.reset_index()
display(ml1m_movies_df.head(5))
print(f'Number of rows removed due to missing links in KG: {num_movies-ml1m_movies_df.shape[0]}')

# Now lets remove videos/items not present in entities_df by merging with movies_to_kg_df
movies_to_kg_df=pd.merge(movies_to_kg_df, entities_df, on=['entity_url'])
print('\nUpdated movies_to_kg_df: ')
display(movies_to_kg_df.head(5))
print(f'Correct Mapped Videos/Items: {movies_to_kg_df.shape[0]}')

print(f'\nMovies Before: {ml1m_movies_df.shape[0]}')
movies_to_kg_df=movies_to_kg_df[movies_to_kg_df.entity_id.isin(entities_df.entity_id)]
print(f'Number of rows due to missing entity data in KG: {movies_to_kg_df.shape[0]}')

# NOW LETS PROPAGATE CHANGES CONSISTENTLY
num_ratings=ml1m_ratings_df.shape[0]
ml1m_ratings_df=ml1m_ratings_df[ml1m_ratings_df['movie_id'].isin(movies_to_kg_df.dataset_id)]
ml1m_ratings_df.reset_index()
display(ml1m_ratings_df.head(5))
print(f"Num rows removed due to interaction with removed movies: {num_ratings-ml1m_ratings_df.shape[0]}")
# Out:
# Items in original dataset: 3883
# Items correctly mapped in KG: 3301
#    movie_id                          movie_name                         genre
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# 5         6                         Heat (1995)         Action|Crime|Thriller
# Number of rows removed due to missing links in KG: 582
#
# Updated movies_to_kg_df:
#    dataset_id                movie_name  \
# 0         781    Stealing Beauty (1996)
# 1        1799      Suicide Kings (1997)
# 2         521  Romeo Is Bleeding (1993)
# 3        3596            Screwed (2000)
# 4        3682       Magnum Force (1973)
#
#                                         entity_url  entity_id
# 0      http://dbpedia.org/resource/Stealing_Beauty       5474
# 1        http://dbpedia.org/resource/Suicide_Kings       9337
# 2    http://dbpedia.org/resource/Romeo_Is_Bleeding       8520
# 3  http://dbpedia.org/resource/Screwed_(2000_film)       4713
# 4         http://dbpedia.org/resource/Magnum_Force      14676
# Correct Mapped Videos/Items: 3266
#
# Movies Before: 3301
# Number of rows due to missing entity data in KG: 3266
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291
# Num rows removed due to interaction with removed movies: 58904

# %%
# NOW LETS REDUCE DATASET TO ITS K-CORE, so discard items and/ore users that occur less than k items in ratings
counts_col_user=ml1m_ratings_df.groupby('user_id')['user_id'].transform(len)
counts_col_movies=ml1m_ratings_df.groupby('movie_id')['movie_id'].transform(len)
print(counts_col_user.head(5))

k_user, k_movie=5,5 #LESS THAN 5 OCCURRENCES DISCARDED
mask_user=counts_col_user>=k_user
mask_movies=counts_col_movies>=k_movie
print(mask_movies.head(5))

print(f'\nNum ratings before: {ml1m_ratings_df.shape[0]}')
ml1m_ratings_df=ml1m_ratings_df[mask_user & mask_movies]
print(f'Num ratings after: {ml1m_ratings_df.shape[0]}')
display(ml1m_ratings_df.head(5))

# now propagate these changes
ml1m_users_df=ml1m_users_df[ml1m_users_df.UserID.isin(ml1m_ratings_df.user_id.unique())]
ml1m_movies_df=ml1m_movies_df[ml1m_movies_df.movie_id.isin(ml1m_ratings_df.movie_id.unique())]
print(f'Final Num Users: {ml1m_users_df.shape[0]}, Num Movies: {ml1m_movies_df.shape[0]}')
# Out:
# 0    48
# 1    48
# 2    48
# 3    48
# 4    48
# Name: user_id, dtype: int64
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: movie_id, dtype: bool
#
# Num ratings before: 941305
# Num ratings after: 940963
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291
# Final Num Users: 6040, Num Movies: 3030

# %%
# NOW AS THE CHANGES ARE MADE WHAT NEEDED IS TO PROPAGATE SAME CHANGES INTO KG DATA
from knowledge_graph_utils import propagate_item_removal_to_kg
movies_to_kg_df, entities_df, kg_df=propagate_item_removal_to_kg(ml1m_movies_df, movies_to_kg_df, entities_df, kg_df)
# Out:
# Removed 236 entries from i2kg map.
# Removed 236 entries from e_map
# Removed 11916 triplets from kg_df

# %% [markdown]
# **NOW DONE WITH PRE-PROCESSING OF DATASET**

# %%
ml1m_preprocessed_path='data/ml1m/preprocessed'

# SAVE IN Standard Format for Users
#remove unnecessary data
ml1m_users_df=ml1m_users_df.drop(["Gender", "Age", "Occupation", "Zip-code"], axis=1)
display(ml1m_users_df.head(5))
#add new_id as per Standard format
ml1m_users_df.insert(0, 'new_id', range(ml1m_users_df.shape[0]))
display(ml1m_users_df.head(5))
#save
ml1m_users_df.to_csv(f'{ml1m_preprocessed_path}/users.txt', header=["new_id", "raw_dataset_id"], index=False, sep='\t', mode='w+')
user_id2new_id=dict(zip(ml1m_users_df['UserID'], ml1m_users_df.new_id))

# SAVE IN Standard Format for Movies
ml1m_movies_df=ml1m_movies_df.drop(["movie_name", "genre"], axis=1)
ml1m_movies_df.insert(0, 'new_id', range(ml1m_movies_df.shape[0]))
display(ml1m_movies_df.head(5))
print(ml1m_movies_df.shape[0])
ml1m_movies_df.to_csv(f'{ml1m_preprocessed_path}/products.txt', header=["new_id", "raw_dataset_id"], index=False, sep='\t', mode='w+')
movie_id2new_id = dict(zip(ml1m_movies_df["movie_id"], ml1m_movies_df.new_id))

# CHANGE IN RATINGS
ml1m_ratings_df["user_id"]=ml1m_ratings_df['user_id'].map(user_id2new_id)
ml1m_ratings_df["movie_id"]=ml1m_ratings_df['movie_id'].map(movie_id2new_id)
display(ml1m_ratings_df.head(5))
#Save ratings
ml1m_ratings_df.to_csv(f'{ml1m_preprocessed_path}/ratings.txt', header=["uid", "pid", "rating", "timestamp"], index=False, sep='\t', mode='w+')
# Out:
#    UserID
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#    new_id  UserID
# 0       0       1
# 1       1       2
# 2       2       3
# 3       3       4
# 4       4       5
#    new_id  movie_id
# 1       0         2
# 2       1         3
# 3       2         4
# 4       3         5
# 5       4         6
# 3030
#    user_id  movie_id  rating  timestamp
# 0        0       872       5  978300760
# 1        0       537       3  978302109
# 2        0       679       3  978301968
# 3        0      2606       4  978300275
# 4        0      1790       5  978824291

# %%
# Preprocessing KG
#keep only relation between entity head and entity tail
display(movies_to_kg_df.head(5))
print(f"Number of movies correctly mapped: {movies_to_kg_df.shape[0]}")
mask=kg_df['entity_tail'].isin(movies_to_kg_df.entity_id) & ~kg_df['entity_head'].isin(movies_to_kg_df.entity_id)
kg_df.loc[mask, ['entity_head', 'entity_tail']]=(kg_df.loc[mask, ['entity_tail', 'entity_head']].values)

n_of_triplets=kg_df.shape[0]
kg_df=kg_df[(kg_df['entity_head'].isin(movies_to_kg_df.entity_id) & ~kg_df['entity_tail'].isin(movies_to_kg_df.entity_id))]
display(kg_df.head(5))
print(f"Number of triplets before: {n_of_triplets}")
print(f"Number of triplets after: {kg_df.shape[0]}")

print(len(kg_df.relation.unique()))
# Out:
#    dataset_id                movie_name  \
# 0         781    Stealing Beauty (1996)
# 1        1799      Suicide Kings (1997)
# 2         521  Romeo Is Bleeding (1993)
# 3        3596            Screwed (2000)
# 4        3682       Magnum Force (1973)
#
#                                         entity_url  entity_id
# 0      http://dbpedia.org/resource/Stealing_Beauty       5474
# 1        http://dbpedia.org/resource/Suicide_Kings       9337
# 2    http://dbpedia.org/resource/Romeo_Is_Bleeding       8520
# 3  http://dbpedia.org/resource/Screwed_(2000_film)       4713
# 4         http://dbpedia.org/resource/Magnum_Force      14676
# Number of movies correctly mapped: 3030
#    entity_head  entity_tail  relation
# 0         9386         4955        12
# 1         6851         1770         1
# 2          210         5210         8
# 3         4205          406        12
# 4        11533        12345         3
# Number of triplets before: 422273
# Number of triplets after: 409887
# 20

# %%
# Make the KG more dense discarding relations or entities that appear less than k times
v=kg_df[['relation']]
n_of_triplets=kg_df.shape[0]
kg_df=kg_df[v.replace(v.apply(pd.Series.value_counts)).gt(300).all(1)]
display(kg_df.head(5))
print(f"Number of triplets before: {n_of_triplets}")
print(f"Number of triplets after: {kg_df.shape[0]}")

print(len(kg_df.relation.unique()))

# Update our relations_df keeping only the relations that are currently in our kg_df and save them in r_map_filtered.dat
display(relations_df)
relations_df=relations_df[relations_df['relation_id'].isin(kg_df.relation.unique())]
relations_df.reset_index()
display(relations_df.head(5))

# remove senseless relations semantically
relations_df=relations_df[(relations_df['relation_id'] != 13) & (relations_df['relation_id'] != 8)]
display(relations_df)

# Propagate this change in e_map and kg_df.
print(f"Triplets before: {kg_df.shape[0]}")
kg_df=kg_df[kg_df.relation.isin(relations_df.relation_id)]
print(f"Triplets after: {kg_df.shape[0]}")
print(f"Entities before: {entities_df.shape[0]}")
entities_df=entities_df[entities_df.entity_id.isin(kg_df.entity_head) | entities_df.entity_id.isin(kg_df.entity_tail)]
print(f"Entities after: {entities_df.shape[0]}")
# Out:
#    entity_head  entity_tail  relation
# 0         9386         4955        12
# 1         6851         1770         1
# 2          210         5210         8
# 3         4205          406        12
# 4        11533        12345         3
# Number of triplets before: 409887
# Number of triplets after: 409477
# 13
#     relation_id                                     relation_url
# 0             0       http://dbpedia.org/ontology/cinematography
# 1             1  http://dbpedia.org/property/productionCompanies
# 2             2             http://dbpedia.org/property/composer
# 3             3                 http://purl.org/dc/terms/subject
# 4             4          http://dbpedia.org/ontology/openingFilm
# 5             5     http://www.w3.org/2000/01/rdf-schema#seeAlso
# 6             6                http://dbpedia.org/property/story
# 7             7               http://dbpedia.org/ontology/series
# 8             8  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 9             9              http://dbpedia.org/ontology/basedOn
# 10           10             http://dbpedia.org/ontology/starring
# 11           11              http://dbpedia.org/ontology/country
# 12           12     http://dbpedia.org/ontology/wikiPageWikiLink
# 13           13        http://purl.org/linguistics/gold/hypernym
# 14           14              http://dbpedia.org/ontology/editing
# 15           15            http://dbpedia.org/property/producers
# 16           16           http://dbpedia.org/property/allWriting
# 17           17          http://dbpedia.org/property/notableWork
# 18           18             http://dbpedia.org/ontology/director
# 19           19                http://dbpedia.org/ontology/award
#    relation_id                                     relation_url
# 0            0       http://dbpedia.org/ontology/cinematography
# 1            1  http://dbpedia.org/property/productionCompanies
# 2            2             http://dbpedia.org/property/composer
# 3            3                 http://purl.org/dc/terms/subject
# 8            8  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#     relation_id                                     relation_url
# 0             0       http://dbpedia.org/ontology/cinematography
# 1             1  http://dbpedia.org/property/productionCompanies
# 2             2             http://dbpedia.org/property/composer
# 3             3                 http://purl.org/dc/terms/subject
# 10           10             http://dbpedia.org/ontology/starring
# 11           11              http://dbpedia.org/ontology/country
# 12           12     http://dbpedia.org/ontology/wikiPageWikiLink
# 14           14              http://dbpedia.org/ontology/editing
# 15           15            http://dbpedia.org/property/producers
# 16           16           http://dbpedia.org/property/allWriting
# 18           18             http://dbpedia.org/ontology/director
# Triplets before: 409477
# Triplets after: 323499
# Entities before: 14472
# Entities after: 13804

# %%
# Saving preprocessed KG in Standard Format
ml1m_kg_preprocessed_path='data/ml1m/preprocessed/'
relations_df.to_csv(f'{ml1m_kg_preprocessed_path}/r_map.txt', header=["relation_id", "relation_url"], index=False, sep='\t', mode='w+')
display(entities_df.head(5))
entities_df.to_csv(f'{ml1m_kg_preprocessed_path}/e_map.txt', header=["entity_id", "entity_url"], index=False, sep='\t', mode='w+')
display(movies_to_kg_df.head(5))
movies_to_kg_df.to_csv(f'{ml1m_kg_preprocessed_path}/i2kg_map.txt', header=["dataset_id", "movie_name", 'entity_url', 'entity_id'], index=False, sep='\t', mode='w+')
display(kg_df.head(5))
kg_df.to_csv(f'{ml1m_kg_preprocessed_path}/kg_final.txt', header=["entity_head", "entity_tail", 'relation'], index=False, sep='\t', mode='w+')
# Out:
#    entity_id                                         entity_url
# 0          0            http://dbpedia.org/resource/Roger_Carel
# 1          1       http://dbpedia.org/resource/Soundtrack_album
# 2          2           http://dbpedia.org/resource/1982_in_film
# 3          3  http://dbpedia.org/resource/Category:Films_set...
# 4          4            http://dbpedia.org/resource/Plaza_Hotel
#    dataset_id                movie_name  \
# 0         781    Stealing Beauty (1996)
# 1        1799      Suicide Kings (1997)
# 2         521  Romeo Is Bleeding (1993)
# 3        3596            Screwed (2000)
# 4        3682       Magnum Force (1973)
#
#                                         entity_url  entity_id
# 0      http://dbpedia.org/resource/Stealing_Beauty       5474
# 1        http://dbpedia.org/resource/Suicide_Kings       9337
# 2    http://dbpedia.org/resource/Romeo_Is_Bleeding       8520
# 3  http://dbpedia.org/resource/Screwed_(2000_film)       4713
# 4         http://dbpedia.org/resource/Magnum_Force      14676
#    entity_head  entity_tail  relation
# 0         9386         4955        12
# 1         6851         1770         1
# 3         4205          406        12
# 4        11533        12345         3
# 5         2075         7182        12

# %% [markdown]
# ## Policy Guided Path Reasoning (PGPR)

# %% [markdown]
# * KG in explainable recommendation method used: Reasoning path methods as they are able to extract paths and recommendations in the same step. This guarantees a high fidelity since the produced explanation path encode the real model functioning, so the chosen paths do encode model behavior
# * Knowledge graphs paths are composed by a chain of entities and relations. For the task of explainable recommendation, we are interested in user-centric paths that start from a user entity and end with a product entity.
# * To constraint the possible paths and select only those that follow some structured rules (based on length and semantics) what is done is to define meta-paths. Why? because some paths don't make sense or not user-centeric. A metapath, is relation sequence connecting two entities. Is proposed to capture the structural and semantic relation between objects.
# * A great property of the paths is that they are a great source to produce textual explanations and some methods are able to extract them while performing recommendations. This is particular useful since in this way the path encodes the real model functioning. Paths have this property and are composed with a step-by-step approach take the name of reasoning paths
# * TransE is a translational knowledge graph embedding (KGE). KGE methods aims to learn a low-dimensional representation of a KGs' entities and relations while preserving their semantic meaning.
# * WHAT IS PGPR? PGPR is a Self-Explainable recommendation method that relies on a Reinforcement Learning (RL) agent conditioned on the user and trained to navigate to potentially relevant products. Starting from a user node, the agent will conduct an explicit multi-step path reasoning over the graph, so as to discover suitable items in the graph for recommendation to the target user. The path from the user A to the product can be used to explain the recommendation.
# <br>

# %% [markdown]
# To model a **RL problem** we need to define 4 things:
# - `Enviroment`: The KG
# - `Set of States`: Nodes of the KG
# - `Set of Actions`: Edges of the KG
# - `Reward`: Computed using transE embedding
#
# all KG RL work: <a href='models/PGPR/kg_env.py'>path</a>
# <br>
# * During the learning, the agent starts from a random user node (state), and will search for valid paths (according to our metapaths) that bring to a product composing the path step-by-step until we reach a product.
# * The Action Space (which action we can take as next) is done by considering both random actions (exploration) and actions that maximize the scoring function (exploitation).
# * To handle the possible high amount of actions avaiable, the authors also proposed a pruning based on the scoring function.
# * The Multi-Hop scoring function for a path of len k is defined as the sum of the dot product in the translational space (<...>) between the entities that compose the path.

# %%
import gzip
from mapper import write_time_based_train_test_split

dataset_name='ml1m'
#create a time-based user-based split, this means that every user (user-based) has the first n_train ratings sorted by timestamp (time-based) in train and the others in the test set.

train_size=0.8
write_time_based_train_test_split(dataset_name, "pgpr", train_size)

#these files, every row represents an interaction and is formatted as uid, pid, 1, timestamp separated by \t.
with gzip.open('data/ml1m/preprocessed/pgpr/train.txt.gz', 'rt') as train_file:
    for i, line in enumerate(train_file):
        if i>5: 
            break
        print(line)
train_file.close()
# Out:
# 0	2455	1	978300019
#
#
#
# 0	937	1	978300055
#
#
#
# 0	1279	1	978300055

# %%
#run PGPR, we need to have the files in a format which is readable by the model. In particular, PGPR needs to have all the entities (e.g., actor, category) and relations (e.g. starring, belong to) grouped by their type.
from mapper import map_to_PGPR

map_to_PGPR(dataset_name)

with gzip.open("data/ml1m/preprocessed/pgpr/editor.txt.gz", 'rt') as editor_file:
    for i, line in enumerate(editor_file):
        if i > 5: break
        print(line)
editor_file.close()

with gzip.open("data/ml1m/preprocessed/pgpr/category_p_ca.txt.gz", 'rt') as belong_to_file:
    for i, line in enumerate(belong_to_file):
        if i > 5: break
        print(line)
belong_to_file.close()
# Out:
# new_id	name
#
#
#
# 0	14104
#
#
#
# 1	648
#
#
#
# 1132	1194	109	1741	638	770	1817	1218	718	1401	1230	679	802	1021	849	1167	1742	187	680	1818	450	1117	1660	1121	509	328	1044	1496	1154
#
#
#
# 1167	315	652	691	942	1500	990	1144	1022	1316	1230	638	1004
#
#
#
# 727	1144	1359	905	276	1230	1167	255	291	1128	1424	638	990	1748	417

# %%
#Run PGPR preprocessing
# %cd models/PGPR/
# Out:
# c:\Users\IT\OneDrive\Desktop\Projects\sem8_RS_project\models\PGPR

# %%
# %run preprocess.py --dataset {dataset_name}
# Out:
# Load ml1m dataset from file...
# Load user of size 6040
# Load product of size 3030
# Load actor of size 2411
# Load composer of size 295
# Load director of size 601
# Load producer of size 669
# Load production_company of size 305
# Load category of size 1821
# Load country of size 32
# Load editor of size 220
# Load writter of size 665
# Load cinematographer of size 236
# Load wikipage of size 10839
# Load directed_by of size 1884
# Load composed_by of size 2005
# Load produced_by_company of size 4329
# Load produced_by_producer of size 2287
# Load produced_in of size 311
# Load starring of size 9599
# Load belong_to of size 40470
# Load edited_by of size 1193
# Load wrote_by of size 1756
# Load cinematography_by of size 1480
# Load related_to of size 258018
# 0 0
# Load review of size 750376 with positive reviews= 0  and negative reviews= 750376
# Create ml1m knowledge graph from dataset...
# Load entities...
# Total 27177 nodes.
# Load reviews...
# Total 1500752 review edges.
# Load knowledge produced_by_company...
# Total 8458 produced_by_company edges.
# Load knowledge produced_by_producer...
# Total 4574 produced_by_producer edges.
# Load knowledge edited_by...
# Total 2386 edited_by edges.
# Load knowledge wrote_by...
# Total 3512 wrote_by edges.
# Load knowledge cinematography_by...
# Total 2960 cinematography_by edges.
# Load knowledge belong_to...
# Total 80940 belong_to edges.
# Load knowledge directed_by...
# Total 3768 directed_by edges.
# Load knowledge starring...
# Total 19166 starring edges.
# Load knowledge composed_by...
# Total 4010 composed_by edges.
# Load knowledge produced_in...
# Total 622 produced_in edges.
# Load knowledge related_to...
# Total 439624 related_to edges.
# Remove duplicates...
# Compute node degrees...
# Generate ml1m train/test labels.

# %%
#learn the TransE representation of our KG by executing the train_transe_model.py.
# %run train_transe_model --dataset {dataset_name}
# Out:
# ../../data/ml1m/preprocessed/pgpr/tmp
# [INFO]  Namespace(dataset='ml1m', name='train_transe_model', seed=123, gpu='0', epochs=30, batch_size=64, lr=0.5, weight_decay=0, l2_lambda=0, max_grad_norm=5.0, embed_size=100, num_neg_samples=5, steps_per_checkpoint=200, device='cpu', log_dir='../../data/ml1m/preprocessed/pgpr/tmp\\train_transe_model')
# [INFO]  Parameters:['watched', 'produced_by_company', 'produced_by_producer', 'belong_to', 'directed_by', 'starring', 'wrote_by', 'edited_by', 'cinematography_by', 'composed_by', 'produced_in', 'related_to', 'user.weight', 'product.weight', 'actor.weight', 'composer.weight', 'director.weight', 'production_company.weight', 'producer.weight', 'writter.weight', 'editor.weight', 'cinematographer.weight', 'category.weight', 'country.weight', 'wikipage.weight', 'watched_bias.weight', 'produced_by_company_bias.weight', 'produced_by_producer_bias.weight', 'belong_to_bias.weight', 'directed_by_bias.weight', 'starring_bias.weight', 'wrote_by_bias.weight', 'edited_by_bias.weight', 'cinematography_by_bias.weight', 'composed_by_bias.weight', 'produced_in_bias.weight', 'related_to_bias.weight']
# [INFO]  Epoch: 01 | Review: 12800/22511281 | Lr: 0.49972 | Smooth loss: 41.98669
# [INFO]  Epoch: 01 | Review: 25600/22511281 | Lr: 0.49943 | Smooth loss: 36.39988
# [INFO]  Epoch: 01 | Review: 38400/22511281 | Lr: 0.49915 | Smooth loss: 34.30718
# [INFO]  Epoch: 01 | Review: 51200/22511281 | Lr: 0.49886 | Smooth loss: 32.70160
# [INFO]  Epoch: 01 | Review: 64000/22511281 | Lr: 0.49858 | Smooth loss: 31.40295
# [INFO]  Epoch: 01 | Review: 76800/22511281 | Lr: 0.49830 | Smooth loss: 30.27165
# [INFO]  Epoch: 01 | Review: 89600/22511281 | Lr: 0.49801 | Smooth loss: 28.92006
# [INFO]  Epoch: 01 | Review: 102400/22511281 | Lr: 0.49773 | Smooth loss: 27.85468
# [INFO]  Epoch: 01 | Review: 115200/22511281 | Lr: 0.49744 | Smooth loss: 26.44327
# [INFO]  Epoch: 01 | Review: 128000/22511281 | Lr: 0.49716 | Smooth loss: 25.67493
# [INFO]  Epoch: 01 | Review: 140800/22511281 | Lr: 0.49687 | Smooth loss: 24.58629
# [INFO]  Epoch: 01 | Review: 153600/22511281 | Lr: 0.49659 | Smooth loss: 23.55575
# [INFO]  Epoch: 01 | Review: 166400/22511281 | Lr: 0.49631 | Smooth loss: 22.67106
# [INFO]  Epoch: 01 | Review: 179200/22511281 | Lr: 0.49602 | Smooth loss: 21.69201
# [INFO]  Epoch: 01 | Review: 192000/22511281 | Lr: 0.49574 | Smooth loss: 20.92991
# [INFO]  Epoch: 01 | Review: 204800/22511281 | Lr: 0.49545 | Smooth loss: 20.40296
# [INFO]  Epoch: 01 | Review: 217600/22511281 | Lr: 0.49517 | Smooth loss: 19.60514
# [INFO]  Epoch: 01 | Review: 230400/22511281 | Lr: 0.49488 | Smooth loss: 19.25833
# [INFO]  Epoch: 01 | Review: 243200/22511281 | Lr: 0.49460 | Smooth loss: 18.64541
# [INFO]  Epoch: 01 | Review: 256000/22511281 | Lr: 0.49432 | Smooth loss: 17.83495
# [INFO]  Epoch: 01 | Review: 268800/22511281 | Lr: 0.49403 | Smooth loss: 17.74799
# [INFO]  Epoch: 01 | Review: 281600/22511281 | Lr: 0.49375 | Smooth loss: 17.40594
# [INFO]  Epoch: 01 | Review: 294400/22511281 | Lr: 0.49346 | Smooth loss: 16.78644
# [INFO]  Epoch: 01 | Review: 307200/22511281 | Lr: 0.49318 | Smooth loss: 16.53158
# [INFO]  Epoch: 01 | Review: 320000/22511281 | Lr: 0.49289 | Smooth loss: 16.17230
# [INFO]  Epoch: 01 | Review: 332800/22511281 | Lr: 0.49261 | Smooth loss: 16.04620
# [INFO]  Epoch: 01 | Review: 345600/22511281 | Lr: 0.49233 | Smooth loss: 15.40901
# [INFO]  Epoch: 01 | Review: 358400/22511281 | Lr: 0.49204 | Smooth loss: 15.08952
# [INFO]  Epoch: 01 | Review: 371200/22511281 | Lr: 0.49176 | Smooth loss: 15.02023
# [INFO]  Epoch: 01 | Review: 384000/22511281 | Lr: 0.49147 | Smooth loss: 15.00078
# [INFO]  Epoch: 01 | Review: 396800/22511281 | Lr: 0.49119 | Smooth loss: 14.74141
# [INFO]  Epoch: 01 | Review: 409600/22511281 | Lr: 0.49090 | Smooth loss: 14.34764
# [INFO]  Epoch: 01 | Review: 422400/22511281 | Lr: 0.49062 | Smooth loss: 14.46545
# [INFO]  Epoch: 01 | Review: 435200/22511281 | Lr: 0.49034 | Smooth loss: 13.92051
# [INFO]  Epoch: 01 | Review: 448000/22511281 | Lr: 0.49005 | Smooth loss: 13.97486
# [INFO]  Epoch: 01 | Review: 460800/22511281 | Lr: 0.48977 | Smooth loss: 13.69212
# [INFO]  Epoch: 01 | Review: 473600/22511281 | Lr: 0.48948 | Smooth loss: 13.54069
# [INFO]  Epoch: 01 | Review: 486400/22511281 | Lr: 0.48920 | Smooth loss: 13.56695
# [INFO]  Epoch: 01 | Review: 499200/22511281 | Lr: 0.48891 | Smooth loss: 13.34737
# [INFO]  Epoch: 01 | Review: 512000/22511281 | Lr: 0.48863 | Smooth loss: 13.27322
# [INFO]  Epoch: 01 | Review: 524800/22511281 | Lr: 0.48835 | Smooth loss: 13.19909
# [INFO]  Epoch: 01 | Review: 537600/22511281 | Lr: 0.48806 | Smooth loss: 12.88801
# [INFO]  Epoch: 01 | Review: 550400/22511281 | Lr: 0.48778 | Smooth loss: 12.88328
# [INFO]  Epoch: 01 | Review: 563200/22511281 | Lr: 0.48749 | Smooth loss: 12.68055
# [INFO]  Epoch: 01 | Review: 576000/22511281 | Lr: 0.48721 | Smooth loss: 12.88114
# [INFO]  Epoch: 01 | Review: 588800/22511281 | Lr: 0.48692 | Smooth loss: 12.60698
# [INFO]  Epoch: 01 | Review: 601600/22511281 | Lr: 0.48664 | Smooth loss: 12.42836
# [INFO]  Epoch: 01 | Review: 614400/22511281 | Lr: 0.48635 | Smooth loss: 12.56520
# [INFO]  Epoch: 01 | Review: 627200/22511281 | Lr: 0.48607 | Smooth loss: 12.28352
# [INFO]  Epoch: 01 | Review: 640000/22511281 | Lr: 0.48579 | Smooth loss: 12.17403
# [INFO]  Epoch: 01 | Review: 652800/22511281 | Lr: 0.48550 | Smooth loss: 12.29778
# [INFO]  Epoch: 01 | Review: 665600/22511281 | Lr: 0.48522 | Smooth loss: 12.08406
# [INFO]  Epoch: 01 | Review: 678400/22511281 | Lr: 0.48493 | Smooth loss: 11.99079
# [INFO]  Epoch: 01 | Review: 691200/22511281 | Lr: 0.48465 | Smooth loss: 12.00392
# [INFO]  Epoch: 01 | Review: 704000/22511281 | Lr: 0.48436 | Smooth loss: 11.86757
# [INFO]  Epoch: 01 | Review: 716800/22511281 | Lr: 0.48408 | Smooth loss: 11.86014
# [INFO]  Epoch: 01 | Review: 729600/22511281 | Lr: 0.48380 | Smooth loss: 11.72557
# [INFO]  Epoch: 01 | Review: 742400/22511281 | Lr: 0.48351 | Smooth loss: 11.56132
# [INFO]  Epoch: 02 | Review: 755176/22511281 | Lr: 0.48323 | Smooth loss: 11.65783
# [INFO]  Epoch: 02 | Review: 767976/22511281 | Lr: 0.48294 | Smooth loss: 11.60035
# [INFO]  Epoch: 02 | Review: 780776/22511281 | Lr: 0.48266 | Smooth loss: 11.43631
# [INFO]  Epoch: 02 | Review: 793576/22511281 | Lr: 0.48238 | Smooth loss: 11.36069
# [INFO]  Epoch: 02 | Review: 806376/22511281 | Lr: 0.48209 | Smooth loss: 11.16159
# [INFO]  Epoch: 02 | Review: 819176/22511281 | Lr: 0.48181 | Smooth loss: 11.35118
# [INFO]  Epoch: 02 | Review: 831976/22511281 | Lr: 0.48152 | Smooth loss: 11.26240
# [INFO]  Epoch: 02 | Review: 844776/22511281 | Lr: 0.48124 | Smooth loss: 11.35523
# [INFO]  Epoch: 02 | Review: 857576/22511281 | Lr: 0.48095 | Smooth loss: 11.04686
# [INFO]  Epoch: 02 | Review: 870376/22511281 | Lr: 0.48067 | Smooth loss: 11.33879
# [INFO]  Epoch: 02 | Review: 883176/22511281 | Lr: 0.48039 | Smooth loss: 11.18435
# [INFO]  Epoch: 02 | Review: 895976/22511281 | Lr: 0.48010 | Smooth loss: 11.28223
# [INFO]  Epoch: 02 | Review: 908776/22511281 | Lr: 0.47982 | Smooth loss: 11.12403
# [INFO]  Epoch: 02 | Review: 921576/22511281 | Lr: 0.47953 | Smooth loss: 10.88858
# [INFO]  Epoch: 02 | Review: 934376/22511281 | Lr: 0.47925 | Smooth loss: 10.96921
# [INFO]  Epoch: 02 | Review: 947176/22511281 | Lr: 0.47896 | Smooth loss: 10.97613
# [INFO]  Epoch: 02 | Review: 959976/22511281 | Lr: 0.47868 | Smooth loss: 10.99875
# [INFO]  Epoch: 02 | Review: 972776/22511281 | Lr: 0.47840 | Smooth loss: 10.67447
# [INFO]  Epoch: 02 | Review: 985576/22511281 | Lr: 0.47811 | Smooth loss: 10.85237
# [INFO]  Epoch: 02 | Review: 998376/22511281 | Lr: 0.47783 | Smooth loss: 10.72206
# [INFO]  Epoch: 02 | Review: 1011176/22511281 | Lr: 0.47754 | Smooth loss: 10.74240
# [INFO]  Epoch: 02 | Review: 1023976/22511281 | Lr: 0.47726 | Smooth loss: 10.58959
# [INFO]  Epoch: 02 | Review: 1036776/22511281 | Lr: 0.47697 | Smooth loss: 10.79536
# [INFO]  Epoch: 02 | Review: 1049576/22511281 | Lr: 0.47669 | Smooth loss: 10.45331
# [INFO]  Epoch: 02 | Review: 1062376/22511281 | Lr: 0.47640 | Smooth loss: 10.51043
# [INFO]  Epoch: 02 | Review: 1075176/22511281 | Lr: 0.47612 | Smooth loss: 10.60738
# [INFO]  Epoch: 02 | Review: 1087976/22511281 | Lr: 0.47584 | Smooth loss: 10.63888
# [INFO]  Epoch: 02 | Review: 1100776/22511281 | Lr: 0.47555 | Smooth loss: 10.64772
# [INFO]  Epoch: 02 | Review: 1113576/22511281 | Lr: 0.47527 | Smooth loss: 10.17692
# [INFO]  Epoch: 02 | Review: 1126376/22511281 | Lr: 0.47498 | Smooth loss: 10.58254
# [INFO]  Epoch: 02 | Review: 1139176/22511281 | Lr: 0.47470 | Smooth loss: 10.39813
# [INFO]  Epoch: 02 | Review: 1151976/22511281 | Lr: 0.47441 | Smooth loss: 10.48650
# [INFO]  Epoch: 02 | Review: 1164776/22511281 | Lr: 0.47413 | Smooth loss: 10.35709
# [INFO]  Epoch: 02 | Review: 1177576/22511281 | Lr: 0.47385 | Smooth loss: 10.29011
# [INFO]  Epoch: 02 | Review: 1190376/22511281 | Lr: 0.47356 | Smooth loss: 10.44525
# [INFO]  Epoch: 02 | Review: 1203176/22511281 | Lr: 0.47328 | Smooth loss: 10.31931
# [INFO]  Epoch: 02 | Review: 1215976/22511281 | Lr: 0.47299 | Smooth loss: 10.28897
# [INFO]  Epoch: 02 | Review: 1228776/22511281 | Lr: 0.47271 | Smooth loss: 10.31154
# [INFO]  Epoch: 02 | Review: 1241576/22511281 | Lr: 0.47242 | Smooth loss: 10.16307
# [INFO]  Epoch: 02 | Review: 1254376/22511281 | Lr: 0.47214 | Smooth loss: 10.21650
# [INFO]  Epoch: 02 | Review: 1267176/22511281 | Lr: 0.47186 | Smooth loss: 10.01673
# [INFO]  Epoch: 02 | Review: 1279976/22511281 | Lr: 0.47157 | Smooth loss: 10.32822
# [INFO]  Epoch: 02 | Review: 1292776/22511281 | Lr: 0.47129 | Smooth loss: 10.16618
# [INFO]  Epoch: 02 | Review: 1305576/22511281 | Lr: 0.47100 | Smooth loss: 10.09683
# [INFO]  Epoch: 02 | Review: 1318376/22511281 | Lr: 0.47072 | Smooth loss: 10.21778
# [INFO]  Epoch: 02 | Review: 1331176/22511281 | Lr: 0.47043 | Smooth loss: 10.21587
# [INFO]  Epoch: 02 | Review: 1343976/22511281 | Lr: 0.47015 | Smooth loss: 10.07941
# [INFO]  Epoch: 02 | Review: 1356776/22511281 | Lr: 0.46987 | Smooth loss: 10.12876
# [INFO]  Epoch: 02 | Review: 1369576/22511281 | Lr: 0.46958 | Smooth loss: 9.95856
# [INFO]  Epoch: 02 | Review: 1382376/22511281 | Lr: 0.46930 | Smooth loss: 10.15584
# [INFO]  Epoch: 02 | Review: 1395176/22511281 | Lr: 0.46901 | Smooth loss: 9.90504
# [INFO]  Epoch: 02 | Review: 1407976/22511281 | Lr: 0.46873 | Smooth loss: 9.88603
# [INFO]  Epoch: 02 | Review: 1420776/22511281 | Lr: 0.46844 | Smooth loss: 10.04220
# [INFO]  Epoch: 02 | Review: 1433576/22511281 | Lr: 0.46816 | Smooth loss: 9.91755
# [INFO]  Epoch: 02 | Review: 1446376/22511281 | Lr: 0.46788 | Smooth loss: 10.03670
# [INFO]  Epoch: 02 | Review: 1459176/22511281 | Lr: 0.46759 | Smooth loss: 9.73548
# [INFO]  Epoch: 02 | Review: 1471976/22511281 | Lr: 0.46731 | Smooth loss: 9.96845
# [INFO]  Epoch: 02 | Review: 1484776/22511281 | Lr: 0.46702 | Smooth loss: 9.97123
# [INFO]  Epoch: 02 | Review: 1497576/22511281 | Lr: 0.46674 | Smooth loss: 9.79833
# [INFO]  Epoch: 03 | Review: 1510352/22511281 | Lr: 0.46645 | Smooth loss: 9.80917
# [INFO]  Epoch: 03 | Review: 1523152/22511281 | Lr: 0.46617 | Smooth loss: 9.72937
# [INFO]  Epoch: 03 | Review: 1535952/22511281 | Lr: 0.46589 | Smooth loss: 9.89699
# [INFO]  Epoch: 03 | Review: 1548752/22511281 | Lr: 0.46560 | Smooth loss: 9.80189
# [INFO]  Epoch: 03 | Review: 1561552/22511281 | Lr: 0.46532 | Smooth loss: 9.64396
# [INFO]  Epoch: 03 | Review: 1574352/22511281 | Lr: 0.46503 | Smooth loss: 9.93348
# [INFO]  Epoch: 03 | Review: 1587152/22511281 | Lr: 0.46475 | Smooth loss: 9.95776
# [INFO]  Epoch: 03 | Review: 1599952/22511281 | Lr: 0.46446 | Smooth loss: 9.59328
# [INFO]  Epoch: 03 | Review: 1612752/22511281 | Lr: 0.46418 | Smooth loss: 9.39358
# [INFO]  Epoch: 03 | Review: 1625552/22511281 | Lr: 0.46390 | Smooth loss: 9.69086
# [INFO]  Epoch: 03 | Review: 1638352/22511281 | Lr: 0.46361 | Smooth loss: 9.68001
# [INFO]  Epoch: 03 | Review: 1651152/22511281 | Lr: 0.46333 | Smooth loss: 9.75519
# [INFO]  Epoch: 03 | Review: 1663952/22511281 | Lr: 0.46304 | Smooth loss: 9.67428
# [INFO]  Epoch: 03 | Review: 1676752/22511281 | Lr: 0.46276 | Smooth loss: 9.76772
# [INFO]  Epoch: 03 | Review: 1689552/22511281 | Lr: 0.46247 | Smooth loss: 9.48669
# [INFO]  Epoch: 03 | Review: 1702352/22511281 | Lr: 0.46219 | Smooth loss: 9.57592
# [INFO]  Epoch: 03 | Review: 1715152/22511281 | Lr: 0.46191 | Smooth loss: 9.64635
# [INFO]  Epoch: 03 | Review: 1727952/22511281 | Lr: 0.46162 | Smooth loss: 9.82614
# [INFO]  Epoch: 03 | Review: 1740752/22511281 | Lr: 0.46134 | Smooth loss: 9.47742
# [INFO]  Epoch: 03 | Review: 1753552/22511281 | Lr: 0.46105 | Smooth loss: 9.36181
# [INFO]  Epoch: 03 | Review: 1766352/22511281 | Lr: 0.46077 | Smooth loss: 9.66112
# [INFO]  Epoch: 03 | Review: 1779152/22511281 | Lr: 0.46048 | Smooth loss: 9.59842
# [INFO]  Epoch: 03 | Review: 1791952/22511281 | Lr: 0.46020 | Smooth loss: 9.63955
# [INFO]  Epoch: 03 | Review: 1804752/22511281 | Lr: 0.45992 | Smooth loss: 9.67363
# [INFO]  Epoch: 03 | Review: 1817552/22511281 | Lr: 0.45963 | Smooth loss: 9.50741
# [INFO]  Epoch: 03 | Review: 1830352/22511281 | Lr: 0.45935 | Smooth loss: 9.37536
# [INFO]  Epoch: 03 | Review: 1843152/22511281 | Lr: 0.45906 | Smooth loss: 9.25851
# [INFO]  Epoch: 03 | Review: 1855952/22511281 | Lr: 0.45878 | Smooth loss: 9.34412
# [INFO]  Epoch: 03 | Review: 1868752/22511281 | Lr: 0.45849 | Smooth loss: 9.64219
# [INFO]  Epoch: 03 | Review: 1881552/22511281 | Lr: 0.45821 | Smooth loss: 9.58385
# [INFO]  Epoch: 03 | Review: 1894352/22511281 | Lr: 0.45793 | Smooth loss: 9.51642
# [INFO]  Epoch: 03 | Review: 1907152/22511281 | Lr: 0.45764 | Smooth loss: 9.34140
# [INFO]  Epoch: 03 | Review: 1919952/22511281 | Lr: 0.45736 | Smooth loss: 9.25672
# [INFO]  Epoch: 03 | Review: 1932752/22511281 | Lr: 0.45707 | Smooth loss: 9.25315
# [INFO]  Epoch: 03 | Review: 1945552/22511281 | Lr: 0.45679 | Smooth loss: 9.05624
# [INFO]  Epoch: 03 | Review: 1958352/22511281 | Lr: 0.45650 | Smooth loss: 9.41504
# [INFO]  Epoch: 03 | Review: 1971152/22511281 | Lr: 0.45622 | Smooth loss: 9.18181
# [INFO]  Epoch: 03 | Review: 1983952/22511281 | Lr: 0.45594 | Smooth loss: 9.14845
# [INFO]  Epoch: 03 | Review: 1996752/22511281 | Lr: 0.45565 | Smooth loss: 9.29914
# [INFO]  Epoch: 03 | Review: 2009552/22511281 | Lr: 0.45537 | Smooth loss: 9.01815
# [INFO]  Epoch: 03 | Review: 2022352/22511281 | Lr: 0.45508 | Smooth loss: 9.20378
# [INFO]  Epoch: 03 | Review: 2035152/22511281 | Lr: 0.45480 | Smooth loss: 9.27027
# [INFO]  Epoch: 03 | Review: 2047952/22511281 | Lr: 0.45451 | Smooth loss: 9.28253
# [INFO]  Epoch: 03 | Review: 2060752/22511281 | Lr: 0.45423 | Smooth loss: 9.40783
# [INFO]  Epoch: 03 | Review: 2073552/22511281 | Lr: 0.45395 | Smooth loss: 9.49622
# [INFO]  Epoch: 03 | Review: 2086352/22511281 | Lr: 0.45366 | Smooth loss: 9.27795
# [INFO]  Epoch: 03 | Review: 2099152/22511281 | Lr: 0.45338 | Smooth loss: 9.15957
# [INFO]  Epoch: 03 | Review: 2111952/22511281 | Lr: 0.45309 | Smooth loss: 9.25256
# [INFO]  Epoch: 03 | Review: 2124752/22511281 | Lr: 0.45281 | Smooth loss: 9.22246
# [INFO]  Epoch: 03 | Review: 2137552/22511281 | Lr: 0.45252 | Smooth loss: 9.21344
# [INFO]  Epoch: 03 | Review: 2150352/22511281 | Lr: 0.45224 | Smooth loss: 9.10199
# [INFO]  Epoch: 03 | Review: 2163152/22511281 | Lr: 0.45196 | Smooth loss: 9.29172
# [INFO]  Epoch: 03 | Review: 2175952/22511281 | Lr: 0.45167 | Smooth loss: 9.19072
# [INFO]  Epoch: 03 | Review: 2188752/22511281 | Lr: 0.45139 | Smooth loss: 9.05766
# [INFO]  Epoch: 03 | Review: 2201552/22511281 | Lr: 0.45110 | Smooth loss: 9.07826
# [INFO]  Epoch: 03 | Review: 2214352/22511281 | Lr: 0.45082 | Smooth loss: 8.88786
# [INFO]  Epoch: 03 | Review: 2227152/22511281 | Lr: 0.45053 | Smooth loss: 9.16317
# [INFO]  Epoch: 03 | Review: 2239952/22511281 | Lr: 0.45025 | Smooth loss: 9.20469
# [INFO]  Epoch: 04 | Review: 2252728/22511281 | Lr: 0.44997 | Smooth loss: 9.15434
# [INFO]  Epoch: 04 | Review: 2265528/22511281 | Lr: 0.44968 | Smooth loss: 8.85822
# [INFO]  Epoch: 04 | Review: 2278328/22511281 | Lr: 0.44940 | Smooth loss: 8.94638
# [INFO]  Epoch: 04 | Review: 2291128/22511281 | Lr: 0.44911 | Smooth loss: 9.07481
# [INFO]  Epoch: 04 | Review: 2303928/22511281 | Lr: 0.44883 | Smooth loss: 8.91938
# [INFO]  Epoch: 04 | Review: 2316728/22511281 | Lr: 0.44854 | Smooth loss: 9.12680
# [INFO]  Epoch: 04 | Review: 2329528/22511281 | Lr: 0.44826 | Smooth loss: 9.03925
# [INFO]  Epoch: 04 | Review: 2342328/22511281 | Lr: 0.44798 | Smooth loss: 9.08472
# [INFO]  Epoch: 04 | Review: 2355128/22511281 | Lr: 0.44769 | Smooth loss: 8.79926
# [INFO]  Epoch: 04 | Review: 2367928/22511281 | Lr: 0.44741 | Smooth loss: 9.04053
# [INFO]  Epoch: 04 | Review: 2380728/22511281 | Lr: 0.44712 | Smooth loss: 9.07995
# [INFO]  Epoch: 04 | Review: 2393528/22511281 | Lr: 0.44684 | Smooth loss: 9.00846
# [INFO]  Epoch: 04 | Review: 2406328/22511281 | Lr: 0.44655 | Smooth loss: 8.95690
# [INFO]  Epoch: 04 | Review: 2419128/22511281 | Lr: 0.44627 | Smooth loss: 8.87786
# [INFO]  Epoch: 04 | Review: 2431928/22511281 | Lr: 0.44599 | Smooth loss: 9.04819
# [INFO]  Epoch: 04 | Review: 2444728/22511281 | Lr: 0.44570 | Smooth loss: 8.71891
# [INFO]  Epoch: 04 | Review: 2457528/22511281 | Lr: 0.44542 | Smooth loss: 8.71516
# [INFO]  Epoch: 04 | Review: 2470328/22511281 | Lr: 0.44513 | Smooth loss: 9.04915
# [INFO]  Epoch: 04 | Review: 2483128/22511281 | Lr: 0.44485 | Smooth loss: 8.90631
# [INFO]  Epoch: 04 | Review: 2495928/22511281 | Lr: 0.44456 | Smooth loss: 8.85399
# [INFO]  Epoch: 04 | Review: 2508728/22511281 | Lr: 0.44428 | Smooth loss: 8.95891
# [INFO]  Epoch: 04 | Review: 2521528/22511281 | Lr: 0.44400 | Smooth loss: 8.85100
# [INFO]  Epoch: 04 | Review: 2534328/22511281 | Lr: 0.44371 | Smooth loss: 8.83080
# [INFO]  Epoch: 04 | Review: 2547128/22511281 | Lr: 0.44343 | Smooth loss: 8.92678
# [INFO]  Epoch: 04 | Review: 2559928/22511281 | Lr: 0.44314 | Smooth loss: 8.88972
# [INFO]  Epoch: 04 | Review: 2572728/22511281 | Lr: 0.44286 | Smooth loss: 8.90601
# [INFO]  Epoch: 04 | Review: 2585528/22511281 | Lr: 0.44257 | Smooth loss: 8.95684
# [INFO]  Epoch: 04 | Review: 2598328/22511281 | Lr: 0.44229 | Smooth loss: 8.74675
# [INFO]  Epoch: 04 | Review: 2611128/22511281 | Lr: 0.44201 | Smooth loss: 8.82165
# [INFO]  Epoch: 04 | Review: 2623928/22511281 | Lr: 0.44172 | Smooth loss: 8.88186
# [INFO]  Epoch: 04 | Review: 2636728/22511281 | Lr: 0.44144 | Smooth loss: 8.66382
# [INFO]  Epoch: 04 | Review: 2649528/22511281 | Lr: 0.44115 | Smooth loss: 8.76644
# [INFO]  Epoch: 04 | Review: 2662328/22511281 | Lr: 0.44087 | Smooth loss: 8.75889
# [INFO]  Epoch: 04 | Review: 2675128/22511281 | Lr: 0.44058 | Smooth loss: 8.96548
# [INFO]  Epoch: 04 | Review: 2687928/22511281 | Lr: 0.44030 | Smooth loss: 8.64071
# [INFO]  Epoch: 04 | Review: 2700728/22511281 | Lr: 0.44002 | Smooth loss: 8.59559
# [INFO]  Epoch: 04 | Review: 2713528/22511281 | Lr: 0.43973 | Smooth loss: 8.73981
# [INFO]  Epoch: 04 | Review: 2726328/22511281 | Lr: 0.43945 | Smooth loss: 8.86698
# [INFO]  Epoch: 04 | Review: 2739128/22511281 | Lr: 0.43916 | Smooth loss: 8.78551
# [INFO]  Epoch: 04 | Review: 2751928/22511281 | Lr: 0.43888 | Smooth loss: 8.98504
# [INFO]  Epoch: 04 | Review: 2764728/22511281 | Lr: 0.43859 | Smooth loss: 8.72649
# [INFO]  Epoch: 04 | Review: 2777528/22511281 | Lr: 0.43831 | Smooth loss: 8.65264
# [INFO]  Epoch: 04 | Review: 2790328/22511281 | Lr: 0.43803 | Smooth loss: 9.01512
# [INFO]  Epoch: 04 | Review: 2803128/22511281 | Lr: 0.43774 | Smooth loss: 8.67778
# [INFO]  Epoch: 04 | Review: 2815928/22511281 | Lr: 0.43746 | Smooth loss: 8.77997
# [INFO]  Epoch: 04 | Review: 2828728/22511281 | Lr: 0.43717 | Smooth loss: 8.59443
# [INFO]  Epoch: 04 | Review: 2841528/22511281 | Lr: 0.43689 | Smooth loss: 8.86394
# [INFO]  Epoch: 04 | Review: 2854328/22511281 | Lr: 0.43660 | Smooth loss: 8.92022
# [INFO]  Epoch: 04 | Review: 2867128/22511281 | Lr: 0.43632 | Smooth loss: 8.68955
# [INFO]  Epoch: 04 | Review: 2879928/22511281 | Lr: 0.43604 | Smooth loss: 8.60046
# [INFO]  Epoch: 04 | Review: 2892728/22511281 | Lr: 0.43575 | Smooth loss: 8.61669
# [INFO]  Epoch: 04 | Review: 2905528/22511281 | Lr: 0.43547 | Smooth loss: 8.79474
# [INFO]  Epoch: 04 | Review: 2918328/22511281 | Lr: 0.43518 | Smooth loss: 8.69864
# [INFO]  Epoch: 04 | Review: 2931128/22511281 | Lr: 0.43490 | Smooth loss: 8.64722
# [INFO]  Epoch: 04 | Review: 2943928/22511281 | Lr: 0.43461 | Smooth loss: 8.59260
# [INFO]  Epoch: 04 | Review: 2956728/22511281 | Lr: 0.43433 | Smooth loss: 8.47633
# [INFO]  Epoch: 04 | Review: 2969528/22511281 | Lr: 0.43404 | Smooth loss: 8.55232
# [INFO]  Epoch: 04 | Review: 2982328/22511281 | Lr: 0.43376 | Smooth loss: 8.63935
# [INFO]  Epoch: 04 | Review: 2995128/22511281 | Lr: 0.43348 | Smooth loss: 8.57230
# [INFO]  Epoch: 05 | Review: 3007904/22511281 | Lr: 0.43319 | Smooth loss: 8.28134
# [INFO]  Epoch: 05 | Review: 3020704/22511281 | Lr: 0.43291 | Smooth loss: 8.57450
# [INFO]  Epoch: 05 | Review: 3033504/22511281 | Lr: 0.43262 | Smooth loss: 8.57589
# [INFO]  Epoch: 05 | Review: 3046304/22511281 | Lr: 0.43234 | Smooth loss: 8.63792
# [INFO]  Epoch: 05 | Review: 3059104/22511281 | Lr: 0.43206 | Smooth loss: 8.42100
# [INFO]  Epoch: 05 | Review: 3071904/22511281 | Lr: 0.43177 | Smooth loss: 8.83421
# [INFO]  Epoch: 05 | Review: 3084704/22511281 | Lr: 0.43149 | Smooth loss: 8.58477
# [INFO]  Epoch: 05 | Review: 3097504/22511281 | Lr: 0.43120 | Smooth loss: 8.51053
# [INFO]  Epoch: 05 | Review: 3110304/22511281 | Lr: 0.43092 | Smooth loss: 8.30832
# [INFO]  Epoch: 05 | Review: 3123104/22511281 | Lr: 0.43063 | Smooth loss: 8.54651
# [INFO]  Epoch: 05 | Review: 3135904/22511281 | Lr: 0.43035 | Smooth loss: 8.39854
# [INFO]  Epoch: 05 | Review: 3148704/22511281 | Lr: 0.43007 | Smooth loss: 8.61349
# [INFO]  Epoch: 05 | Review: 3161504/22511281 | Lr: 0.42978 | Smooth loss: 8.57204
# [INFO]  Epoch: 05 | Review: 3174304/22511281 | Lr: 0.42950 | Smooth loss: 8.50491
# [INFO]  Epoch: 05 | Review: 3187104/22511281 | Lr: 0.42921 | Smooth loss: 8.52630
# [INFO]  Epoch: 05 | Review: 3199904/22511281 | Lr: 0.42893 | Smooth loss: 8.55518
# [INFO]  Epoch: 05 | Review: 3212704/22511281 | Lr: 0.42864 | Smooth loss: 8.36239
# [INFO]  Epoch: 05 | Review: 3225504/22511281 | Lr: 0.42836 | Smooth loss: 8.25411
# [INFO]  Epoch: 05 | Review: 3238304/22511281 | Lr: 0.42808 | Smooth loss: 8.31474
# [INFO]  Epoch: 05 | Review: 3251104/22511281 | Lr: 0.42779 | Smooth loss: 8.61251
# [INFO]  Epoch: 05 | Review: 3263904/22511281 | Lr: 0.42751 | Smooth loss: 8.57224
# [INFO]  Epoch: 05 | Review: 3276704/22511281 | Lr: 0.42722 | Smooth loss: 8.38215
# [INFO]  Epoch: 05 | Review: 3289504/22511281 | Lr: 0.42694 | Smooth loss: 8.40258
# [INFO]  Epoch: 05 | Review: 3302304/22511281 | Lr: 0.42665 | Smooth loss: 8.54057
# [INFO]  Epoch: 05 | Review: 3315104/22511281 | Lr: 0.42637 | Smooth loss: 8.44125
# [INFO]  Epoch: 05 | Review: 3327904/22511281 | Lr: 0.42609 | Smooth loss: 8.70596
# [INFO]  Epoch: 05 | Review: 3340704/22511281 | Lr: 0.42580 | Smooth loss: 8.76512
# [INFO]  Epoch: 05 | Review: 3353504/22511281 | Lr: 0.42552 | Smooth loss: 8.27685
# [INFO]  Epoch: 05 | Review: 3366304/22511281 | Lr: 0.42523 | Smooth loss: 8.54978
# [INFO]  Epoch: 05 | Review: 3379104/22511281 | Lr: 0.42495 | Smooth loss: 8.59912
# [INFO]  Epoch: 05 | Review: 3391904/22511281 | Lr: 0.42466 | Smooth loss: 8.36607
# [INFO]  Epoch: 05 | Review: 3404704/22511281 | Lr: 0.42438 | Smooth loss: 8.57532
# [INFO]  Epoch: 05 | Review: 3417504/22511281 | Lr: 0.42409 | Smooth loss: 8.35207
# [INFO]  Epoch: 05 | Review: 3430304/22511281 | Lr: 0.42381 | Smooth loss: 8.44583
# [INFO]  Epoch: 05 | Review: 3443104/22511281 | Lr: 0.42353 | Smooth loss: 8.43943
# [INFO]  Epoch: 05 | Review: 3455904/22511281 | Lr: 0.42324 | Smooth loss: 8.35312
# [INFO]  Epoch: 05 | Review: 3468704/22511281 | Lr: 0.42296 | Smooth loss: 8.38300
# [INFO]  Epoch: 05 | Review: 3481504/22511281 | Lr: 0.42267 | Smooth loss: 8.25096
# [INFO]  Epoch: 05 | Review: 3494304/22511281 | Lr: 0.42239 | Smooth loss: 8.01128
# [INFO]  Epoch: 05 | Review: 3507104/22511281 | Lr: 0.42210 | Smooth loss: 8.31833
# [INFO]  Epoch: 05 | Review: 3519904/22511281 | Lr: 0.42182 | Smooth loss: 8.45232
# [INFO]  Epoch: 05 | Review: 3532704/22511281 | Lr: 0.42154 | Smooth loss: 8.42477
# [INFO]  Epoch: 05 | Review: 3545504/22511281 | Lr: 0.42125 | Smooth loss: 8.17597
# [INFO]  Epoch: 05 | Review: 3558304/22511281 | Lr: 0.42097 | Smooth loss: 8.20113
# [INFO]  Epoch: 05 | Review: 3571104/22511281 | Lr: 0.42068 | Smooth loss: 8.44105
# [INFO]  Epoch: 05 | Review: 3583904/22511281 | Lr: 0.42040 | Smooth loss: 8.49334
# [INFO]  Epoch: 05 | Review: 3596704/22511281 | Lr: 0.42011 | Smooth loss: 8.24591
# [INFO]  Epoch: 05 | Review: 3609504/22511281 | Lr: 0.41983 | Smooth loss: 8.26555
# [INFO]  Epoch: 05 | Review: 3622304/22511281 | Lr: 0.41955 | Smooth loss: 8.25475
# [INFO]  Epoch: 05 | Review: 3635104/22511281 | Lr: 0.41926 | Smooth loss: 8.33529
# [INFO]  Epoch: 05 | Review: 3647904/22511281 | Lr: 0.41898 | Smooth loss: 8.22397
# [INFO]  Epoch: 05 | Review: 3660704/22511281 | Lr: 0.41869 | Smooth loss: 8.29864
# [INFO]  Epoch: 05 | Review: 3673504/22511281 | Lr: 0.41841 | Smooth loss: 8.44682
# [INFO]  Epoch: 05 | Review: 3686304/22511281 | Lr: 0.41812 | Smooth loss: 8.31475
# [INFO]  Epoch: 05 | Review: 3699104/22511281 | Lr: 0.41784 | Smooth loss: 8.52422
# [INFO]  Epoch: 05 | Review: 3711904/22511281 | Lr: 0.41756 | Smooth loss: 8.46746
# [INFO]  Epoch: 05 | Review: 3724704/22511281 | Lr: 0.41727 | Smooth loss: 8.28460
# [INFO]  Epoch: 05 | Review: 3737504/22511281 | Lr: 0.41699 | Smooth loss: 8.36738
# [INFO]  Epoch: 05 | Review: 3750304/22511281 | Lr: 0.41670 | Smooth loss: 8.49306
# [INFO]  Epoch: 06 | Review: 3763080/22511281 | Lr: 0.41642 | Smooth loss: 8.14793
# [INFO]  Epoch: 06 | Review: 3775880/22511281 | Lr: 0.41614 | Smooth loss: 8.21225
# [INFO]  Epoch: 06 | Review: 3788680/22511281 | Lr: 0.41585 | Smooth loss: 8.06656
# [INFO]  Epoch: 06 | Review: 3801480/22511281 | Lr: 0.41557 | Smooth loss: 8.02440
# [INFO]  Epoch: 06 | Review: 3814280/22511281 | Lr: 0.41528 | Smooth loss: 8.05744
# [INFO]  Epoch: 06 | Review: 3827080/22511281 | Lr: 0.41500 | Smooth loss: 8.27569
# [INFO]  Epoch: 06 | Review: 3839880/22511281 | Lr: 0.41471 | Smooth loss: 7.90744
# [INFO]  Epoch: 06 | Review: 3852680/22511281 | Lr: 0.41443 | Smooth loss: 8.12733
# [INFO]  Epoch: 06 | Review: 3865480/22511281 | Lr: 0.41414 | Smooth loss: 8.17731
# [INFO]  Epoch: 06 | Review: 3878280/22511281 | Lr: 0.41386 | Smooth loss: 8.44716
# [INFO]  Epoch: 06 | Review: 3891080/22511281 | Lr: 0.41358 | Smooth loss: 8.12222
# [INFO]  Epoch: 06 | Review: 3903880/22511281 | Lr: 0.41329 | Smooth loss: 8.24180
# [INFO]  Epoch: 06 | Review: 3916680/22511281 | Lr: 0.41301 | Smooth loss: 7.93369
# [INFO]  Epoch: 06 | Review: 3929480/22511281 | Lr: 0.41272 | Smooth loss: 7.91071
# [INFO]  Epoch: 06 | Review: 3942280/22511281 | Lr: 0.41244 | Smooth loss: 8.11518
# [INFO]  Epoch: 06 | Review: 3955080/22511281 | Lr: 0.41215 | Smooth loss: 8.20261
# [INFO]  Epoch: 06 | Review: 3967880/22511281 | Lr: 0.41187 | Smooth loss: 8.10983
# [INFO]  Epoch: 06 | Review: 3980680/22511281 | Lr: 0.41159 | Smooth loss: 8.30624
# [INFO]  Epoch: 06 | Review: 3993480/22511281 | Lr: 0.41130 | Smooth loss: 8.03278
# [INFO]  Epoch: 06 | Review: 4006280/22511281 | Lr: 0.41102 | Smooth loss: 7.94434
# [INFO]  Epoch: 06 | Review: 4019080/22511281 | Lr: 0.41073 | Smooth loss: 7.94912
# [INFO]  Epoch: 06 | Review: 4031880/22511281 | Lr: 0.41045 | Smooth loss: 8.27820
# [INFO]  Epoch: 06 | Review: 4044680/22511281 | Lr: 0.41016 | Smooth loss: 8.00237
# [INFO]  Epoch: 06 | Review: 4057480/22511281 | Lr: 0.40988 | Smooth loss: 8.35007
# [INFO]  Epoch: 06 | Review: 4070280/22511281 | Lr: 0.40960 | Smooth loss: 8.21007
# [INFO]  Epoch: 06 | Review: 4083080/22511281 | Lr: 0.40931 | Smooth loss: 7.98919
# [INFO]  Epoch: 06 | Review: 4095880/22511281 | Lr: 0.40903 | Smooth loss: 8.21767
# [INFO]  Epoch: 06 | Review: 4108680/22511281 | Lr: 0.40874 | Smooth loss: 8.04568
# [INFO]  Epoch: 06 | Review: 4121480/22511281 | Lr: 0.40846 | Smooth loss: 8.06104
# [INFO]  Epoch: 06 | Review: 4134280/22511281 | Lr: 0.40817 | Smooth loss: 7.96124
# [INFO]  Epoch: 06 | Review: 4147080/22511281 | Lr: 0.40789 | Smooth loss: 8.18476
# [INFO]  Epoch: 06 | Review: 4159880/22511281 | Lr: 0.40761 | Smooth loss: 7.75447
# [INFO]  Epoch: 06 | Review: 4172680/22511281 | Lr: 0.40732 | Smooth loss: 7.77502
# [INFO]  Epoch: 06 | Review: 4185480/22511281 | Lr: 0.40704 | Smooth loss: 7.93788
# [INFO]  Epoch: 06 | Review: 4198280/22511281 | Lr: 0.40675 | Smooth loss: 8.03938
# [INFO]  Epoch: 06 | Review: 4211080/22511281 | Lr: 0.40647 | Smooth loss: 8.18389
# [INFO]  Epoch: 06 | Review: 4223880/22511281 | Lr: 0.40618 | Smooth loss: 8.07265
# [INFO]  Epoch: 06 | Review: 4236680/22511281 | Lr: 0.40590 | Smooth loss: 8.02563
# [INFO]  Epoch: 06 | Review: 4249480/22511281 | Lr: 0.40562 | Smooth loss: 8.36735
# [INFO]  Epoch: 06 | Review: 4262280/22511281 | Lr: 0.40533 | Smooth loss: 8.12458
# [INFO]  Epoch: 06 | Review: 4275080/22511281 | Lr: 0.40505 | Smooth loss: 8.07425
# [INFO]  Epoch: 06 | Review: 4287880/22511281 | Lr: 0.40476 | Smooth loss: 8.08250
# [INFO]  Epoch: 06 | Review: 4300680/22511281 | Lr: 0.40448 | Smooth loss: 8.12011
# [INFO]  Epoch: 06 | Review: 4313480/22511281 | Lr: 0.40419 | Smooth loss: 7.93113
# [INFO]  Epoch: 06 | Review: 4326280/22511281 | Lr: 0.40391 | Smooth loss: 8.08398
# [INFO]  Epoch: 06 | Review: 4339080/22511281 | Lr: 0.40363 | Smooth loss: 8.08370
# [INFO]  Epoch: 06 | Review: 4351880/22511281 | Lr: 0.40334 | Smooth loss: 7.86937
# [INFO]  Epoch: 06 | Review: 4364680/22511281 | Lr: 0.40306 | Smooth loss: 7.91006
# [INFO]  Epoch: 06 | Review: 4377480/22511281 | Lr: 0.40277 | Smooth loss: 8.22847
# [INFO]  Epoch: 06 | Review: 4390280/22511281 | Lr: 0.40249 | Smooth loss: 7.98168
# [INFO]  Epoch: 06 | Review: 4403080/22511281 | Lr: 0.40220 | Smooth loss: 7.84597
# [INFO]  Epoch: 06 | Review: 4415880/22511281 | Lr: 0.40192 | Smooth loss: 8.10727
# [INFO]  Epoch: 06 | Review: 4428680/22511281 | Lr: 0.40164 | Smooth loss: 7.97126
# [INFO]  Epoch: 06 | Review: 4441480/22511281 | Lr: 0.40135 | Smooth loss: 8.13686
# [INFO]  Epoch: 06 | Review: 4454280/22511281 | Lr: 0.40107 | Smooth loss: 8.03290
# [INFO]  Epoch: 06 | Review: 4467080/22511281 | Lr: 0.40078 | Smooth loss: 7.80095
# [INFO]  Epoch: 06 | Review: 4479880/22511281 | Lr: 0.40050 | Smooth loss: 7.91218
# [INFO]  Epoch: 06 | Review: 4492680/22511281 | Lr: 0.40021 | Smooth loss: 7.93880
# [INFO]  Epoch: 07 | Review: 4505456/22511281 | Lr: 0.39993 | Smooth loss: 7.79698
# [INFO]  Epoch: 07 | Review: 4518256/22511281 | Lr: 0.39965 | Smooth loss: 7.91268
# [INFO]  Epoch: 07 | Review: 4531056/22511281 | Lr: 0.39936 | Smooth loss: 7.79656
# [INFO]  Epoch: 07 | Review: 4543856/22511281 | Lr: 0.39908 | Smooth loss: 7.67664
# [INFO]  Epoch: 07 | Review: 4556656/22511281 | Lr: 0.39879 | Smooth loss: 7.97370
# [INFO]  Epoch: 07 | Review: 4569456/22511281 | Lr: 0.39851 | Smooth loss: 7.99469
# [INFO]  Epoch: 07 | Review: 4582256/22511281 | Lr: 0.39822 | Smooth loss: 7.55105
# [INFO]  Epoch: 07 | Review: 4595056/22511281 | Lr: 0.39794 | Smooth loss: 7.99916
# [INFO]  Epoch: 07 | Review: 4607856/22511281 | Lr: 0.39766 | Smooth loss: 7.84361
# [INFO]  Epoch: 07 | Review: 4620656/22511281 | Lr: 0.39737 | Smooth loss: 8.00803
# [INFO]  Epoch: 07 | Review: 4633456/22511281 | Lr: 0.39709 | Smooth loss: 7.62710
# [INFO]  Epoch: 07 | Review: 4646256/22511281 | Lr: 0.39680 | Smooth loss: 8.09988
# [INFO]  Epoch: 07 | Review: 4659056/22511281 | Lr: 0.39652 | Smooth loss: 7.71749
# [INFO]  Epoch: 07 | Review: 4671856/22511281 | Lr: 0.39623 | Smooth loss: 7.60358
# [INFO]  Epoch: 07 | Review: 4684656/22511281 | Lr: 0.39595 | Smooth loss: 7.94435
# [INFO]  Epoch: 07 | Review: 4697456/22511281 | Lr: 0.39567 | Smooth loss: 7.91089
# [INFO]  Epoch: 07 | Review: 4710256/22511281 | Lr: 0.39538 | Smooth loss: 7.88509
# [INFO]  Epoch: 07 | Review: 4723056/22511281 | Lr: 0.39510 | Smooth loss: 7.54666
# [INFO]  Epoch: 07 | Review: 4735856/22511281 | Lr: 0.39481 | Smooth loss: 7.74441
# [INFO]  Epoch: 07 | Review: 4748656/22511281 | Lr: 0.39453 | Smooth loss: 7.38446
# [INFO]  Epoch: 07 | Review: 4761456/22511281 | Lr: 0.39424 | Smooth loss: 7.92337
# [INFO]  Epoch: 07 | Review: 4774256/22511281 | Lr: 0.39396 | Smooth loss: 7.69419
# [INFO]  Epoch: 07 | Review: 4787056/22511281 | Lr: 0.39368 | Smooth loss: 7.92398
# [INFO]  Epoch: 07 | Review: 4799856/22511281 | Lr: 0.39339 | Smooth loss: 7.64374
# [INFO]  Epoch: 07 | Review: 4812656/22511281 | Lr: 0.39311 | Smooth loss: 7.68819
# [INFO]  Epoch: 07 | Review: 4825456/22511281 | Lr: 0.39282 | Smooth loss: 7.86016
# [INFO]  Epoch: 07 | Review: 4838256/22511281 | Lr: 0.39254 | Smooth loss: 7.81479
# [INFO]  Epoch: 07 | Review: 4851056/22511281 | Lr: 0.39225 | Smooth loss: 7.75189
# [INFO]  Epoch: 07 | Review: 4863856/22511281 | Lr: 0.39197 | Smooth loss: 7.64316
# [INFO]  Epoch: 07 | Review: 4876656/22511281 | Lr: 0.39169 | Smooth loss: 7.85708
# [INFO]  Epoch: 07 | Review: 4889456/22511281 | Lr: 0.39140 | Smooth loss: 7.82876
# [INFO]  Epoch: 07 | Review: 4902256/22511281 | Lr: 0.39112 | Smooth loss: 7.64129
# [INFO]  Epoch: 07 | Review: 4915056/22511281 | Lr: 0.39083 | Smooth loss: 7.60867
# [INFO]  Epoch: 07 | Review: 4927856/22511281 | Lr: 0.39055 | Smooth loss: 7.80416
# [INFO]  Epoch: 07 | Review: 4940656/22511281 | Lr: 0.39026 | Smooth loss: 7.80899
# [INFO]  Epoch: 07 | Review: 4953456/22511281 | Lr: 0.38998 | Smooth loss: 7.75501
# [INFO]  Epoch: 07 | Review: 4966256/22511281 | Lr: 0.38970 | Smooth loss: 7.70861
# [INFO]  Epoch: 07 | Review: 4979056/22511281 | Lr: 0.38941 | Smooth loss: 7.64055
# [INFO]  Epoch: 07 | Review: 4991856/22511281 | Lr: 0.38913 | Smooth loss: 7.72098
# [INFO]  Epoch: 07 | Review: 5004656/22511281 | Lr: 0.38884 | Smooth loss: 7.70609
# [INFO]  Epoch: 07 | Review: 5017456/22511281 | Lr: 0.38856 | Smooth loss: 7.73483
# [INFO]  Epoch: 07 | Review: 5030256/22511281 | Lr: 0.38827 | Smooth loss: 7.76826
# [INFO]  Epoch: 07 | Review: 5043056/22511281 | Lr: 0.38799 | Smooth loss: 7.72397
# [INFO]  Epoch: 07 | Review: 5055856/22511281 | Lr: 0.38771 | Smooth loss: 7.76449
# [INFO]  Epoch: 07 | Review: 5068656/22511281 | Lr: 0.38742 | Smooth loss: 7.63551
# [INFO]  Epoch: 07 | Review: 5081456/22511281 | Lr: 0.38714 | Smooth loss: 7.79067
# [INFO]  Epoch: 07 | Review: 5094256/22511281 | Lr: 0.38685 | Smooth loss: 7.80549
# [INFO]  Epoch: 07 | Review: 5107056/22511281 | Lr: 0.38657 | Smooth loss: 7.65970
# [INFO]  Epoch: 07 | Review: 5119856/22511281 | Lr: 0.38628 | Smooth loss: 7.82013
# [INFO]  Epoch: 07 | Review: 5132656/22511281 | Lr: 0.38600 | Smooth loss: 7.63862
# [INFO]  Epoch: 07 | Review: 5145456/22511281 | Lr: 0.38572 | Smooth loss: 7.72185
# [INFO]  Epoch: 07 | Review: 5158256/22511281 | Lr: 0.38543 | Smooth loss: 7.69775
# [INFO]  Epoch: 07 | Review: 5171056/22511281 | Lr: 0.38515 | Smooth loss: 7.76361
# [INFO]  Epoch: 07 | Review: 5183856/22511281 | Lr: 0.38486 | Smooth loss: 7.70035
# [INFO]  Epoch: 07 | Review: 5196656/22511281 | Lr: 0.38458 | Smooth loss: 7.60381
# [INFO]  Epoch: 07 | Review: 5209456/22511281 | Lr: 0.38429 | Smooth loss: 7.84185
# [INFO]  Epoch: 07 | Review: 5222256/22511281 | Lr: 0.38401 | Smooth loss: 7.53859
# [INFO]  Epoch: 07 | Review: 5235056/22511281 | Lr: 0.38373 | Smooth loss: 7.46539
# [INFO]  Epoch: 07 | Review: 5247856/22511281 | Lr: 0.38344 | Smooth loss: 7.62109
# [INFO]  Epoch: 08 | Review: 5260632/22511281 | Lr: 0.38316 | Smooth loss: 7.56195
# [INFO]  Epoch: 08 | Review: 5273432/22511281 | Lr: 0.38287 | Smooth loss: 7.63275
# [INFO]  Epoch: 08 | Review: 5286232/22511281 | Lr: 0.38259 | Smooth loss: 7.66455
# [INFO]  Epoch: 08 | Review: 5299032/22511281 | Lr: 0.38230 | Smooth loss: 7.75698
# [INFO]  Epoch: 08 | Review: 5311832/22511281 | Lr: 0.38202 | Smooth loss: 7.47191
# [INFO]  Epoch: 08 | Review: 5324632/22511281 | Lr: 0.38174 | Smooth loss: 7.51555
# [INFO]  Epoch: 08 | Review: 5337432/22511281 | Lr: 0.38145 | Smooth loss: 7.72631
# [INFO]  Epoch: 08 | Review: 5350232/22511281 | Lr: 0.38117 | Smooth loss: 7.57989
# [INFO]  Epoch: 08 | Review: 5363032/22511281 | Lr: 0.38088 | Smooth loss: 7.68351
# [INFO]  Epoch: 08 | Review: 5375832/22511281 | Lr: 0.38060 | Smooth loss: 7.43860
# [INFO]  Epoch: 08 | Review: 5388632/22511281 | Lr: 0.38031 | Smooth loss: 7.59134
# [INFO]  Epoch: 08 | Review: 5401432/22511281 | Lr: 0.38003 | Smooth loss: 7.55266
# [INFO]  Epoch: 08 | Review: 5414232/22511281 | Lr: 0.37975 | Smooth loss: 7.56202
# [INFO]  Epoch: 08 | Review: 5427032/22511281 | Lr: 0.37946 | Smooth loss: 7.58504
# [INFO]  Epoch: 08 | Review: 5439832/22511281 | Lr: 0.37918 | Smooth loss: 7.68638
# [INFO]  Epoch: 08 | Review: 5452632/22511281 | Lr: 0.37889 | Smooth loss: 7.50866
# [INFO]  Epoch: 08 | Review: 5465432/22511281 | Lr: 0.37861 | Smooth loss: 7.28050
# [INFO]  Epoch: 08 | Review: 5478232/22511281 | Lr: 0.37832 | Smooth loss: 7.41582
# [INFO]  Epoch: 08 | Review: 5491032/22511281 | Lr: 0.37804 | Smooth loss: 7.51635
# [INFO]  Epoch: 08 | Review: 5503832/22511281 | Lr: 0.37776 | Smooth loss: 7.37468
# [INFO]  Epoch: 08 | Review: 5516632/22511281 | Lr: 0.37747 | Smooth loss: 7.65311
# [INFO]  Epoch: 08 | Review: 5529432/22511281 | Lr: 0.37719 | Smooth loss: 7.41972
# [INFO]  Epoch: 08 | Review: 5542232/22511281 | Lr: 0.37690 | Smooth loss: 7.47541
# [INFO]  Epoch: 08 | Review: 5555032/22511281 | Lr: 0.37662 | Smooth loss: 7.50989
# [INFO]  Epoch: 08 | Review: 5567832/22511281 | Lr: 0.37633 | Smooth loss: 7.33714
# [INFO]  Epoch: 08 | Review: 5580632/22511281 | Lr: 0.37605 | Smooth loss: 7.59810
# [INFO]  Epoch: 08 | Review: 5593432/22511281 | Lr: 0.37577 | Smooth loss: 7.49410
# [INFO]  Epoch: 08 | Review: 5606232/22511281 | Lr: 0.37548 | Smooth loss: 7.61787
# [INFO]  Epoch: 08 | Review: 5619032/22511281 | Lr: 0.37520 | Smooth loss: 7.62060
# [INFO]  Epoch: 08 | Review: 5631832/22511281 | Lr: 0.37491 | Smooth loss: 7.42165
# [INFO]  Epoch: 08 | Review: 5644632/22511281 | Lr: 0.37463 | Smooth loss: 7.52659
# [INFO]  Epoch: 08 | Review: 5657432/22511281 | Lr: 0.37434 | Smooth loss: 7.39250
# [INFO]  Epoch: 08 | Review: 5670232/22511281 | Lr: 0.37406 | Smooth loss: 7.49595
# [INFO]  Epoch: 08 | Review: 5683032/22511281 | Lr: 0.37378 | Smooth loss: 7.49798
# [INFO]  Epoch: 08 | Review: 5695832/22511281 | Lr: 0.37349 | Smooth loss: 7.21231
# [INFO]  Epoch: 08 | Review: 5708632/22511281 | Lr: 0.37321 | Smooth loss: 7.25801
# [INFO]  Epoch: 08 | Review: 5721432/22511281 | Lr: 0.37292 | Smooth loss: 7.50407
# [INFO]  Epoch: 08 | Review: 5734232/22511281 | Lr: 0.37264 | Smooth loss: 7.33515
# [INFO]  Epoch: 08 | Review: 5747032/22511281 | Lr: 0.37235 | Smooth loss: 7.50807
# [INFO]  Epoch: 08 | Review: 5759832/22511281 | Lr: 0.37207 | Smooth loss: 7.57673
# [INFO]  Epoch: 08 | Review: 5772632/22511281 | Lr: 0.37178 | Smooth loss: 7.43260
# [INFO]  Epoch: 08 | Review: 5785432/22511281 | Lr: 0.37150 | Smooth loss: 7.44318
# [INFO]  Epoch: 08 | Review: 5798232/22511281 | Lr: 0.37122 | Smooth loss: 7.59427
# [INFO]  Epoch: 08 | Review: 5811032/22511281 | Lr: 0.37093 | Smooth loss: 7.61593
# [INFO]  Epoch: 08 | Review: 5823832/22511281 | Lr: 0.37065 | Smooth loss: 7.28534
# [INFO]  Epoch: 08 | Review: 5836632/22511281 | Lr: 0.37036 | Smooth loss: 7.39292
# [INFO]  Epoch: 08 | Review: 5849432/22511281 | Lr: 0.37008 | Smooth loss: 7.32020
# [INFO]  Epoch: 08 | Review: 5862232/22511281 | Lr: 0.36979 | Smooth loss: 7.21385
# [INFO]  Epoch: 08 | Review: 5875032/22511281 | Lr: 0.36951 | Smooth loss: 7.36906
# [INFO]  Epoch: 08 | Review: 5887832/22511281 | Lr: 0.36923 | Smooth loss: 7.46808
# [INFO]  Epoch: 08 | Review: 5900632/22511281 | Lr: 0.36894 | Smooth loss: 7.24729
# [INFO]  Epoch: 08 | Review: 5913432/22511281 | Lr: 0.36866 | Smooth loss: 7.52109
# [INFO]  Epoch: 08 | Review: 5926232/22511281 | Lr: 0.36837 | Smooth loss: 7.48638
# [INFO]  Epoch: 08 | Review: 5939032/22511281 | Lr: 0.36809 | Smooth loss: 7.28069
# [INFO]  Epoch: 08 | Review: 5951832/22511281 | Lr: 0.36780 | Smooth loss: 7.41280
# [INFO]  Epoch: 08 | Review: 5964632/22511281 | Lr: 0.36752 | Smooth loss: 7.46416
# [INFO]  Epoch: 08 | Review: 5977432/22511281 | Lr: 0.36724 | Smooth loss: 7.35816
# [INFO]  Epoch: 08 | Review: 5990232/22511281 | Lr: 0.36695 | Smooth loss: 7.29119
# [INFO]  Epoch: 08 | Review: 6003008/22511281 | Lr: 0.36667 | Smooth loss: 7.30715
# [INFO]  Epoch: 09 | Review: 6015808/22511281 | Lr: 0.36638 | Smooth loss: 7.41522
# [INFO]  Epoch: 09 | Review: 6028608/22511281 | Lr: 0.36610 | Smooth loss: 7.23988
# [INFO]  Epoch: 09 | Review: 6041408/22511281 | Lr: 0.36582 | Smooth loss: 7.30604
# [INFO]  Epoch: 09 | Review: 6054208/22511281 | Lr: 0.36553 | Smooth loss: 7.29177
# [INFO]  Epoch: 09 | Review: 6067008/22511281 | Lr: 0.36525 | Smooth loss: 7.32998
# [INFO]  Epoch: 09 | Review: 6079808/22511281 | Lr: 0.36496 | Smooth loss: 7.44602
# [INFO]  Epoch: 09 | Review: 6092608/22511281 | Lr: 0.36468 | Smooth loss: 7.29895
# [INFO]  Epoch: 09 | Review: 6105408/22511281 | Lr: 0.36439 | Smooth loss: 7.23124
# [INFO]  Epoch: 09 | Review: 6118208/22511281 | Lr: 0.36411 | Smooth loss: 7.32809
# [INFO]  Epoch: 09 | Review: 6131008/22511281 | Lr: 0.36383 | Smooth loss: 7.46182
# [INFO]  Epoch: 09 | Review: 6143808/22511281 | Lr: 0.36354 | Smooth loss: 7.28204
# [INFO]  Epoch: 09 | Review: 6156608/22511281 | Lr: 0.36326 | Smooth loss: 7.19939
# [INFO]  Epoch: 09 | Review: 6169408/22511281 | Lr: 0.36297 | Smooth loss: 7.27650
# [INFO]  Epoch: 09 | Review: 6182208/22511281 | Lr: 0.36269 | Smooth loss: 7.10891
# [INFO]  Epoch: 09 | Review: 6195008/22511281 | Lr: 0.36240 | Smooth loss: 7.17891
# [INFO]  Epoch: 09 | Review: 6207808/22511281 | Lr: 0.36212 | Smooth loss: 7.18546
# [INFO]  Epoch: 09 | Review: 6220608/22511281 | Lr: 0.36183 | Smooth loss: 7.24580
# [INFO]  Epoch: 09 | Review: 6233408/22511281 | Lr: 0.36155 | Smooth loss: 7.29839
# [INFO]  Epoch: 09 | Review: 6246208/22511281 | Lr: 0.36127 | Smooth loss: 7.25042
# [INFO]  Epoch: 09 | Review: 6259008/22511281 | Lr: 0.36098 | Smooth loss: 7.14867
# [INFO]  Epoch: 09 | Review: 6271808/22511281 | Lr: 0.36070 | Smooth loss: 7.15658
# [INFO]  Epoch: 09 | Review: 6284608/22511281 | Lr: 0.36041 | Smooth loss: 7.14332
# [INFO]  Epoch: 09 | Review: 6297408/22511281 | Lr: 0.36013 | Smooth loss: 7.29069
# [INFO]  Epoch: 09 | Review: 6310208/22511281 | Lr: 0.35984 | Smooth loss: 7.23997
# [INFO]  Epoch: 09 | Review: 6323008/22511281 | Lr: 0.35956 | Smooth loss: 7.40128
# [INFO]  Epoch: 09 | Review: 6335808/22511281 | Lr: 0.35928 | Smooth loss: 7.43712
# [INFO]  Epoch: 09 | Review: 6348608/22511281 | Lr: 0.35899 | Smooth loss: 7.34433
# [INFO]  Epoch: 09 | Review: 6361408/22511281 | Lr: 0.35871 | Smooth loss: 7.24365
# [INFO]  Epoch: 09 | Review: 6374208/22511281 | Lr: 0.35842 | Smooth loss: 7.33320
# [INFO]  Epoch: 09 | Review: 6387008/22511281 | Lr: 0.35814 | Smooth loss: 7.40976
# [INFO]  Epoch: 09 | Review: 6399808/22511281 | Lr: 0.35785 | Smooth loss: 7.29261
# [INFO]  Epoch: 09 | Review: 6412608/22511281 | Lr: 0.35757 | Smooth loss: 7.13136
# [INFO]  Epoch: 09 | Review: 6425408/22511281 | Lr: 0.35729 | Smooth loss: 7.33806
# [INFO]  Epoch: 09 | Review: 6438208/22511281 | Lr: 0.35700 | Smooth loss: 7.17344
# [INFO]  Epoch: 09 | Review: 6451008/22511281 | Lr: 0.35672 | Smooth loss: 7.07877
# [INFO]  Epoch: 09 | Review: 6463808/22511281 | Lr: 0.35643 | Smooth loss: 7.33611
# [INFO]  Epoch: 09 | Review: 6476608/22511281 | Lr: 0.35615 | Smooth loss: 7.29935
# [INFO]  Epoch: 09 | Review: 6489408/22511281 | Lr: 0.35586 | Smooth loss: 7.22524
# [INFO]  Epoch: 09 | Review: 6502208/22511281 | Lr: 0.35558 | Smooth loss: 7.11295
# [INFO]  Epoch: 09 | Review: 6515008/22511281 | Lr: 0.35530 | Smooth loss: 7.34120
# [INFO]  Epoch: 09 | Review: 6527808/22511281 | Lr: 0.35501 | Smooth loss: 7.20449
# [INFO]  Epoch: 09 | Review: 6540608/22511281 | Lr: 0.35473 | Smooth loss: 7.08130
# [INFO]  Epoch: 09 | Review: 6553408/22511281 | Lr: 0.35444 | Smooth loss: 7.12177
# [INFO]  Epoch: 09 | Review: 6566208/22511281 | Lr: 0.35416 | Smooth loss: 7.21484
# [INFO]  Epoch: 09 | Review: 6579008/22511281 | Lr: 0.35387 | Smooth loss: 7.13665
# [INFO]  Epoch: 09 | Review: 6591808/22511281 | Lr: 0.35359 | Smooth loss: 7.16743
# [INFO]  Epoch: 09 | Review: 6604608/22511281 | Lr: 0.35331 | Smooth loss: 7.23146
# [INFO]  Epoch: 09 | Review: 6617408/22511281 | Lr: 0.35302 | Smooth loss: 7.03912
# [INFO]  Epoch: 09 | Review: 6630208/22511281 | Lr: 0.35274 | Smooth loss: 7.36929
# [INFO]  Epoch: 09 | Review: 6643008/22511281 | Lr: 0.35245 | Smooth loss: 7.17461
# [INFO]  Epoch: 09 | Review: 6655808/22511281 | Lr: 0.35217 | Smooth loss: 7.19689
# [INFO]  Epoch: 09 | Review: 6668608/22511281 | Lr: 0.35188 | Smooth loss: 7.29170
# [INFO]  Epoch: 09 | Review: 6681408/22511281 | Lr: 0.35160 | Smooth loss: 7.07661
# [INFO]  Epoch: 09 | Review: 6694208/22511281 | Lr: 0.35132 | Smooth loss: 7.10384
# [INFO]  Epoch: 09 | Review: 6707008/22511281 | Lr: 0.35103 | Smooth loss: 7.21106
# [INFO]  Epoch: 09 | Review: 6719808/22511281 | Lr: 0.35075 | Smooth loss: 7.27930
# [INFO]  Epoch: 09 | Review: 6732608/22511281 | Lr: 0.35046 | Smooth loss: 7.24330
# [INFO]  Epoch: 09 | Review: 6745408/22511281 | Lr: 0.35018 | Smooth loss: 7.21679
# [INFO]  Epoch: 10 | Review: 6758184/22511281 | Lr: 0.34989 | Smooth loss: 7.17396
# [INFO]  Epoch: 10 | Review: 6770984/22511281 | Lr: 0.34961 | Smooth loss: 7.03872
# [INFO]  Epoch: 10 | Review: 6783784/22511281 | Lr: 0.34933 | Smooth loss: 7.03517
# [INFO]  Epoch: 10 | Review: 6796584/22511281 | Lr: 0.34904 | Smooth loss: 7.06924
# [INFO]  Epoch: 10 | Review: 6809384/22511281 | Lr: 0.34876 | Smooth loss: 7.05308
# [INFO]  Epoch: 10 | Review: 6822184/22511281 | Lr: 0.34847 | Smooth loss: 7.28298
# [INFO]  Epoch: 10 | Review: 6834984/22511281 | Lr: 0.34819 | Smooth loss: 7.05091
# [INFO]  Epoch: 10 | Review: 6847784/22511281 | Lr: 0.34790 | Smooth loss: 6.95102
# [INFO]  Epoch: 10 | Review: 6860584/22511281 | Lr: 0.34762 | Smooth loss: 6.96685
# [INFO]  Epoch: 10 | Review: 6873384/22511281 | Lr: 0.34734 | Smooth loss: 7.19101
# [INFO]  Epoch: 10 | Review: 6886184/22511281 | Lr: 0.34705 | Smooth loss: 6.90037
# [INFO]  Epoch: 10 | Review: 6898984/22511281 | Lr: 0.34677 | Smooth loss: 7.07216
# [INFO]  Epoch: 10 | Review: 6911784/22511281 | Lr: 0.34648 | Smooth loss: 6.99051
# [INFO]  Epoch: 10 | Review: 6924584/22511281 | Lr: 0.34620 | Smooth loss: 7.15729
# [INFO]  Epoch: 10 | Review: 6937384/22511281 | Lr: 0.34591 | Smooth loss: 6.94962
# [INFO]  Epoch: 10 | Review: 6950184/22511281 | Lr: 0.34563 | Smooth loss: 7.06729
# [INFO]  Epoch: 10 | Review: 6962984/22511281 | Lr: 0.34535 | Smooth loss: 7.08251
# [INFO]  Epoch: 10 | Review: 6975784/22511281 | Lr: 0.34506 | Smooth loss: 6.97422
# [INFO]  Epoch: 10 | Review: 6988584/22511281 | Lr: 0.34478 | Smooth loss: 7.27011
# [INFO]  Epoch: 10 | Review: 7001384/22511281 | Lr: 0.34449 | Smooth loss: 6.87896
# [INFO]  Epoch: 10 | Review: 7014184/22511281 | Lr: 0.34421 | Smooth loss: 6.92781
# [INFO]  Epoch: 10 | Review: 7026984/22511281 | Lr: 0.34392 | Smooth loss: 6.97657
# [INFO]  Epoch: 10 | Review: 7039784/22511281 | Lr: 0.34364 | Smooth loss: 6.83669
# [INFO]  Epoch: 10 | Review: 7052584/22511281 | Lr: 0.34336 | Smooth loss: 7.18843
# [INFO]  Epoch: 10 | Review: 7065384/22511281 | Lr: 0.34307 | Smooth loss: 6.94267
# [INFO]  Epoch: 10 | Review: 7078184/22511281 | Lr: 0.34279 | Smooth loss: 7.15085
# [INFO]  Epoch: 10 | Review: 7090984/22511281 | Lr: 0.34250 | Smooth loss: 7.22499
# [INFO]  Epoch: 10 | Review: 7103784/22511281 | Lr: 0.34222 | Smooth loss: 7.04490
# [INFO]  Epoch: 10 | Review: 7116584/22511281 | Lr: 0.34193 | Smooth loss: 7.13372
# [INFO]  Epoch: 10 | Review: 7129384/22511281 | Lr: 0.34165 | Smooth loss: 6.88093
# [INFO]  Epoch: 10 | Review: 7142184/22511281 | Lr: 0.34137 | Smooth loss: 7.07447
# [INFO]  Epoch: 10 | Review: 7154984/22511281 | Lr: 0.34108 | Smooth loss: 7.28147
# [INFO]  Epoch: 10 | Review: 7167784/22511281 | Lr: 0.34080 | Smooth loss: 7.14074
# [INFO]  Epoch: 10 | Review: 7180584/22511281 | Lr: 0.34051 | Smooth loss: 7.07878
# [INFO]  Epoch: 10 | Review: 7193384/22511281 | Lr: 0.34023 | Smooth loss: 6.97450
# [INFO]  Epoch: 10 | Review: 7206184/22511281 | Lr: 0.33994 | Smooth loss: 6.97978
# [INFO]  Epoch: 10 | Review: 7218984/22511281 | Lr: 0.33966 | Smooth loss: 7.05526
# [INFO]  Epoch: 10 | Review: 7231784/22511281 | Lr: 0.33938 | Smooth loss: 7.04516
# [INFO]  Epoch: 10 | Review: 7244584/22511281 | Lr: 0.33909 | Smooth loss: 6.98933
# [INFO]  Epoch: 10 | Review: 7257384/22511281 | Lr: 0.33881 | Smooth loss: 6.89664
# [INFO]  Epoch: 10 | Review: 7270184/22511281 | Lr: 0.33852 | Smooth loss: 7.08016
# [INFO]  Epoch: 10 | Review: 7282984/22511281 | Lr: 0.33824 | Smooth loss: 7.03256
# [INFO]  Epoch: 10 | Review: 7295784/22511281 | Lr: 0.33795 | Smooth loss: 6.99867
# [INFO]  Epoch: 10 | Review: 7308584/22511281 | Lr: 0.33767 | Smooth loss: 6.88109
# ...
# [INFO]  Epoch: 27 | Review: 20236176/22511281 | Lr: 0.05053 | Smooth loss: 5.23622
# [INFO]  Epoch: 27 | Review: 20248976/22511281 | Lr: 0.05025 | Smooth loss: 5.32764
# [INFO]  Epoch: 28 | Review: 20261752/22511281 | Lr: 0.04997 | Smooth loss: 5.15228
# [INFO]  Epoch: 28 | Review: 20274552/22511281 | Lr: 0.04968 | Smooth loss: 5.26107
# [INFO]  Epoch: 28 | Review: 20287352/22511281 | Lr: 0.04940 | Smooth loss: 5.31417
# [INFO]  Epoch: 28 | Review: 20300152/22511281 | Lr: 0.04911 | Smooth loss: 5.25960
# [INFO]  Epoch: 28 | Review: 20312952/22511281 | Lr: 0.04883 | Smooth loss: 5.29877
# [INFO]  Epoch: 28 | Review: 20325752/22511281 | Lr: 0.04854 | Smooth loss: 5.26422
# [INFO]  Epoch: 28 | Review: 20338552/22511281 | Lr: 0.04826 | Smooth loss: 5.34679
# [INFO]  Epoch: 28 | Review: 20351352/22511281 | Lr: 0.04798 | Smooth loss: 5.17605
# [INFO]  Epoch: 28 | Review: 20364152/22511281 | Lr: 0.04769 | Smooth loss: 5.17748
# [INFO]  Epoch: 28 | Review: 20376952/22511281 | Lr: 0.04741 | Smooth loss: 5.19455
# [INFO]  Epoch: 28 | Review: 20389752/22511281 | Lr: 0.04712 | Smooth loss: 5.28578
# [INFO]  Epoch: 28 | Review: 20402552/22511281 | Lr: 0.04684 | Smooth loss: 5.13407
# [INFO]  Epoch: 28 | Review: 20415352/22511281 | Lr: 0.04655 | Smooth loss: 5.22595
# [INFO]  Epoch: 28 | Review: 20428152/22511281 | Lr: 0.04627 | Smooth loss: 5.24340
# [INFO]  Epoch: 28 | Review: 20440952/22511281 | Lr: 0.04599 | Smooth loss: 5.29523
# [INFO]  Epoch: 28 | Review: 20453752/22511281 | Lr: 0.04570 | Smooth loss: 5.24385
# [INFO]  Epoch: 28 | Review: 20466552/22511281 | Lr: 0.04542 | Smooth loss: 5.20989
# [INFO]  Epoch: 28 | Review: 20479352/22511281 | Lr: 0.04513 | Smooth loss: 5.32966
# [INFO]  Epoch: 28 | Review: 20492152/22511281 | Lr: 0.04485 | Smooth loss: 5.23657
# [INFO]  Epoch: 28 | Review: 20504952/22511281 | Lr: 0.04456 | Smooth loss: 5.28912
# [INFO]  Epoch: 28 | Review: 20517752/22511281 | Lr: 0.04428 | Smooth loss: 5.26687
# [INFO]  Epoch: 28 | Review: 20530552/22511281 | Lr: 0.04400 | Smooth loss: 5.35723
# [INFO]  Epoch: 28 | Review: 20543352/22511281 | Lr: 0.04371 | Smooth loss: 5.19593
# [INFO]  Epoch: 28 | Review: 20556152/22511281 | Lr: 0.04343 | Smooth loss: 5.27718
# [INFO]  Epoch: 28 | Review: 20568952/22511281 | Lr: 0.04314 | Smooth loss: 5.30699
# [INFO]  Epoch: 28 | Review: 20581752/22511281 | Lr: 0.04286 | Smooth loss: 5.27528
# [INFO]  Epoch: 28 | Review: 20594552/22511281 | Lr: 0.04257 | Smooth loss: 5.23047
# [INFO]  Epoch: 28 | Review: 20607352/22511281 | Lr: 0.04229 | Smooth loss: 5.25906
# [INFO]  Epoch: 28 | Review: 20620152/22511281 | Lr: 0.04201 | Smooth loss: 5.19905
# [INFO]  Epoch: 28 | Review: 20632952/22511281 | Lr: 0.04172 | Smooth loss: 5.28531
# [INFO]  Epoch: 28 | Review: 20645752/22511281 | Lr: 0.04144 | Smooth loss: 5.19067
# [INFO]  Epoch: 28 | Review: 20658552/22511281 | Lr: 0.04115 | Smooth loss: 5.26055
# [INFO]  Epoch: 28 | Review: 20671352/22511281 | Lr: 0.04087 | Smooth loss: 5.26696
# [INFO]  Epoch: 28 | Review: 20684152/22511281 | Lr: 0.04058 | Smooth loss: 5.22212
# [INFO]  Epoch: 28 | Review: 20696952/22511281 | Lr: 0.04030 | Smooth loss: 5.29029
# [INFO]  Epoch: 28 | Review: 20709752/22511281 | Lr: 0.04002 | Smooth loss: 5.22557
# [INFO]  Epoch: 28 | Review: 20722552/22511281 | Lr: 0.03973 | Smooth loss: 5.26540
# [INFO]  Epoch: 28 | Review: 20735352/22511281 | Lr: 0.03945 | Smooth loss: 5.14657
# [INFO]  Epoch: 28 | Review: 20748152/22511281 | Lr: 0.03916 | Smooth loss: 5.23587
# [INFO]  Epoch: 28 | Review: 20760952/22511281 | Lr: 0.03888 | Smooth loss: 5.20535
# [INFO]  Epoch: 28 | Review: 20773752/22511281 | Lr: 0.03859 | Smooth loss: 5.19071
# [INFO]  Epoch: 28 | Review: 20786552/22511281 | Lr: 0.03831 | Smooth loss: 5.27026
# [INFO]  Epoch: 28 | Review: 20799352/22511281 | Lr: 0.03803 | Smooth loss: 5.26629
# [INFO]  Epoch: 28 | Review: 20812152/22511281 | Lr: 0.03774 | Smooth loss: 5.19378
# [INFO]  Epoch: 28 | Review: 20824952/22511281 | Lr: 0.03746 | Smooth loss: 5.24422
# [INFO]  Epoch: 28 | Review: 20837752/22511281 | Lr: 0.03717 | Smooth loss: 5.18734
# [INFO]  Epoch: 28 | Review: 20850552/22511281 | Lr: 0.03689 | Smooth loss: 5.26481
# [INFO]  Epoch: 28 | Review: 20863352/22511281 | Lr: 0.03660 | Smooth loss: 5.17293
# [INFO]  Epoch: 28 | Review: 20876152/22511281 | Lr: 0.03632 | Smooth loss: 5.23447
# [INFO]  Epoch: 28 | Review: 20888952/22511281 | Lr: 0.03604 | Smooth loss: 5.11344
# [INFO]  Epoch: 28 | Review: 20901752/22511281 | Lr: 0.03575 | Smooth loss: 5.24289
# [INFO]  Epoch: 28 | Review: 20914552/22511281 | Lr: 0.03547 | Smooth loss: 5.12879
# [INFO]  Epoch: 28 | Review: 20927352/22511281 | Lr: 0.03518 | Smooth loss: 5.25651
# [INFO]  Epoch: 28 | Review: 20940152/22511281 | Lr: 0.03490 | Smooth loss: 5.19665
# [INFO]  Epoch: 28 | Review: 20952952/22511281 | Lr: 0.03461 | Smooth loss: 5.29123
# [INFO]  Epoch: 28 | Review: 20965752/22511281 | Lr: 0.03433 | Smooth loss: 5.19807
# [INFO]  Epoch: 28 | Review: 20978552/22511281 | Lr: 0.03404 | Smooth loss: 5.19577
# [INFO]  Epoch: 28 | Review: 20991352/22511281 | Lr: 0.03376 | Smooth loss: 5.16524
# [INFO]  Epoch: 28 | Review: 21004152/22511281 | Lr: 0.03348 | Smooth loss: 5.26589
# [INFO]  Epoch: 29 | Review: 21016928/22511281 | Lr: 0.03319 | Smooth loss: 5.18691
# [INFO]  Epoch: 29 | Review: 21029728/22511281 | Lr: 0.03291 | Smooth loss: 5.22816
# [INFO]  Epoch: 29 | Review: 21042528/22511281 | Lr: 0.03262 | Smooth loss: 5.29292
# [INFO]  Epoch: 29 | Review: 21055328/22511281 | Lr: 0.03234 | Smooth loss: 5.24252
# [INFO]  Epoch: 29 | Review: 21068128/22511281 | Lr: 0.03206 | Smooth loss: 5.29963
# [INFO]  Epoch: 29 | Review: 21080928/22511281 | Lr: 0.03177 | Smooth loss: 5.14369
# [INFO]  Epoch: 29 | Review: 21093728/22511281 | Lr: 0.03149 | Smooth loss: 5.18260
# [INFO]  Epoch: 29 | Review: 21106528/22511281 | Lr: 0.03120 | Smooth loss: 5.21394
# [INFO]  Epoch: 29 | Review: 21119328/22511281 | Lr: 0.03092 | Smooth loss: 5.17187
# [INFO]  Epoch: 29 | Review: 21132128/22511281 | Lr: 0.03063 | Smooth loss: 5.19414
# [INFO]  Epoch: 29 | Review: 21144928/22511281 | Lr: 0.03035 | Smooth loss: 5.21026
# [INFO]  Epoch: 29 | Review: 21157728/22511281 | Lr: 0.03007 | Smooth loss: 5.23377
# [INFO]  Epoch: 29 | Review: 21170528/22511281 | Lr: 0.02978 | Smooth loss: 5.24598
# [INFO]  Epoch: 29 | Review: 21183328/22511281 | Lr: 0.02950 | Smooth loss: 5.14249
# [INFO]  Epoch: 29 | Review: 21196128/22511281 | Lr: 0.02921 | Smooth loss: 5.16829
# [INFO]  Epoch: 29 | Review: 21208928/22511281 | Lr: 0.02893 | Smooth loss: 5.12633
# [INFO]  Epoch: 29 | Review: 21221728/22511281 | Lr: 0.02864 | Smooth loss: 5.15524
# [INFO]  Epoch: 29 | Review: 21234528/22511281 | Lr: 0.02836 | Smooth loss: 5.09197
# [INFO]  Epoch: 29 | Review: 21247328/22511281 | Lr: 0.02808 | Smooth loss: 5.23633
# [INFO]  Epoch: 29 | Review: 21260128/22511281 | Lr: 0.02779 | Smooth loss: 5.22865
# [INFO]  Epoch: 29 | Review: 21272928/22511281 | Lr: 0.02751 | Smooth loss: 5.15103
# [INFO]  Epoch: 29 | Review: 21285728/22511281 | Lr: 0.02722 | Smooth loss: 5.27374
# [INFO]  Epoch: 29 | Review: 21298528/22511281 | Lr: 0.02694 | Smooth loss: 5.20640
# [INFO]  Epoch: 29 | Review: 21311328/22511281 | Lr: 0.02665 | Smooth loss: 5.05753
# [INFO]  Epoch: 29 | Review: 21324128/22511281 | Lr: 0.02637 | Smooth loss: 5.22080
# [INFO]  Epoch: 29 | Review: 21336928/22511281 | Lr: 0.02609 | Smooth loss: 5.29976
# [INFO]  Epoch: 29 | Review: 21349728/22511281 | Lr: 0.02580 | Smooth loss: 5.21106
# [INFO]  Epoch: 29 | Review: 21362528/22511281 | Lr: 0.02552 | Smooth loss: 5.16060
# [INFO]  Epoch: 29 | Review: 21375328/22511281 | Lr: 0.02523 | Smooth loss: 5.11164
# [INFO]  Epoch: 29 | Review: 21388128/22511281 | Lr: 0.02495 | Smooth loss: 5.36795
# [INFO]  Epoch: 29 | Review: 21400928/22511281 | Lr: 0.02466 | Smooth loss: 5.31596
# [INFO]  Epoch: 29 | Review: 21413728/22511281 | Lr: 0.02438 | Smooth loss: 5.22347
# [INFO]  Epoch: 29 | Review: 21426528/22511281 | Lr: 0.02409 | Smooth loss: 5.18410
# [INFO]  Epoch: 29 | Review: 21439328/22511281 | Lr: 0.02381 | Smooth loss: 5.06785
# [INFO]  Epoch: 29 | Review: 21452128/22511281 | Lr: 0.02353 | Smooth loss: 5.15370
# [INFO]  Epoch: 29 | Review: 21464928/22511281 | Lr: 0.02324 | Smooth loss: 5.20603
# [INFO]  Epoch: 29 | Review: 21477728/22511281 | Lr: 0.02296 | Smooth loss: 5.11853
# [INFO]  Epoch: 29 | Review: 21490528/22511281 | Lr: 0.02267 | Smooth loss: 5.17037
# [INFO]  Epoch: 29 | Review: 21503328/22511281 | Lr: 0.02239 | Smooth loss: 5.10693
# [INFO]  Epoch: 29 | Review: 21516128/22511281 | Lr: 0.02210 | Smooth loss: 5.23277
# [INFO]  Epoch: 29 | Review: 21528928/22511281 | Lr: 0.02182 | Smooth loss: 5.12548
# [INFO]  Epoch: 29 | Review: 21541728/22511281 | Lr: 0.02154 | Smooth loss: 5.19969
# [INFO]  Epoch: 29 | Review: 21554528/22511281 | Lr: 0.02125 | Smooth loss: 5.23589
# [INFO]  Epoch: 29 | Review: 21567328/22511281 | Lr: 0.02097 | Smooth loss: 5.22286
# [INFO]  Epoch: 29 | Review: 21580128/22511281 | Lr: 0.02068 | Smooth loss: 5.24694
# [INFO]  Epoch: 29 | Review: 21592928/22511281 | Lr: 0.02040 | Smooth loss: 5.12052
# [INFO]  Epoch: 29 | Review: 21605728/22511281 | Lr: 0.02011 | Smooth loss: 5.07601
# [INFO]  Epoch: 29 | Review: 21618528/22511281 | Lr: 0.01983 | Smooth loss: 5.12265
# [INFO]  Epoch: 29 | Review: 21631328/22511281 | Lr: 0.01955 | Smooth loss: 5.22211
# [INFO]  Epoch: 29 | Review: 21644128/22511281 | Lr: 0.01926 | Smooth loss: 5.24130
# [INFO]  Epoch: 29 | Review: 21656928/22511281 | Lr: 0.01898 | Smooth loss: 5.10616
# [INFO]  Epoch: 29 | Review: 21669728/22511281 | Lr: 0.01869 | Smooth loss: 5.10580
# [INFO]  Epoch: 29 | Review: 21682528/22511281 | Lr: 0.01841 | Smooth loss: 5.19074
# [INFO]  Epoch: 29 | Review: 21695328/22511281 | Lr: 0.01812 | Smooth loss: 5.11620
# [INFO]  Epoch: 29 | Review: 21708128/22511281 | Lr: 0.01784 | Smooth loss: 5.14902
# [INFO]  Epoch: 29 | Review: 21720928/22511281 | Lr: 0.01756 | Smooth loss: 5.23002
# [INFO]  Epoch: 29 | Review: 21733728/22511281 | Lr: 0.01727 | Smooth loss: 5.11355
# [INFO]  Epoch: 29 | Review: 21746528/22511281 | Lr: 0.01699 | Smooth loss: 5.09178
# [INFO]  Epoch: 29 | Review: 21759328/22511281 | Lr: 0.01670 | Smooth loss: 5.17373
# [INFO]  Epoch: 30 | Review: 21772104/22511281 | Lr: 0.01642 | Smooth loss: 5.19631
# [INFO]  Epoch: 30 | Review: 21784904/22511281 | Lr: 0.01614 | Smooth loss: 5.18191
# [INFO]  Epoch: 30 | Review: 21797704/22511281 | Lr: 0.01585 | Smooth loss: 5.17269
# [INFO]  Epoch: 30 | Review: 21810504/22511281 | Lr: 0.01557 | Smooth loss: 5.17058
# [INFO]  Epoch: 30 | Review: 21823304/22511281 | Lr: 0.01528 | Smooth loss: 5.18059
# [INFO]  Epoch: 30 | Review: 21836104/22511281 | Lr: 0.01500 | Smooth loss: 5.26348
# [INFO]  Epoch: 30 | Review: 21848904/22511281 | Lr: 0.01471 | Smooth loss: 5.13506
# [INFO]  Epoch: 30 | Review: 21861704/22511281 | Lr: 0.01443 | Smooth loss: 5.13813
# [INFO]  Epoch: 30 | Review: 21874504/22511281 | Lr: 0.01414 | Smooth loss: 5.23408
# [INFO]  Epoch: 30 | Review: 21887304/22511281 | Lr: 0.01386 | Smooth loss: 5.22833
# [INFO]  Epoch: 30 | Review: 21900104/22511281 | Lr: 0.01358 | Smooth loss: 5.15175
# [INFO]  Epoch: 30 | Review: 21912904/22511281 | Lr: 0.01329 | Smooth loss: 5.14375
# [INFO]  Epoch: 30 | Review: 21925704/22511281 | Lr: 0.01301 | Smooth loss: 5.20366
# [INFO]  Epoch: 30 | Review: 21938504/22511281 | Lr: 0.01272 | Smooth loss: 5.14054
# [INFO]  Epoch: 30 | Review: 21951304/22511281 | Lr: 0.01244 | Smooth loss: 5.16841
# [INFO]  Epoch: 30 | Review: 21964104/22511281 | Lr: 0.01215 | Smooth loss: 5.09861
# [INFO]  Epoch: 30 | Review: 21976904/22511281 | Lr: 0.01187 | Smooth loss: 5.19796
# [INFO]  Epoch: 30 | Review: 21989704/22511281 | Lr: 0.01159 | Smooth loss: 5.09807
# [INFO]  Epoch: 30 | Review: 22002504/22511281 | Lr: 0.01130 | Smooth loss: 5.14499
# [INFO]  Epoch: 30 | Review: 22015304/22511281 | Lr: 0.01102 | Smooth loss: 5.13097
# [INFO]  Epoch: 30 | Review: 22028104/22511281 | Lr: 0.01073 | Smooth loss: 5.17609
# [INFO]  Epoch: 30 | Review: 22040904/22511281 | Lr: 0.01045 | Smooth loss: 5.04893
# [INFO]  Epoch: 30 | Review: 22053704/22511281 | Lr: 0.01016 | Smooth loss: 5.16843
# [INFO]  Epoch: 30 | Review: 22066504/22511281 | Lr: 0.00988 | Smooth loss: 5.09488
# [INFO]  Epoch: 30 | Review: 22079304/22511281 | Lr: 0.00960 | Smooth loss: 5.07134
# [INFO]  Epoch: 30 | Review: 22092104/22511281 | Lr: 0.00931 | Smooth loss: 5.10191
# [INFO]  Epoch: 30 | Review: 22104904/22511281 | Lr: 0.00903 | Smooth loss: 5.17929
# [INFO]  Epoch: 30 | Review: 22117704/22511281 | Lr: 0.00874 | Smooth loss: 5.11187
# [INFO]  Epoch: 30 | Review: 22130504/22511281 | Lr: 0.00846 | Smooth loss: 5.17377
# [INFO]  Epoch: 30 | Review: 22143304/22511281 | Lr: 0.00817 | Smooth loss: 5.16872
# [INFO]  Epoch: 30 | Review: 22156104/22511281 | Lr: 0.00789 | Smooth loss: 5.15066
# [INFO]  Epoch: 30 | Review: 22168904/22511281 | Lr: 0.00761 | Smooth loss: 5.16778
# [INFO]  Epoch: 30 | Review: 22181704/22511281 | Lr: 0.00732 | Smooth loss: 5.07099
# [INFO]  Epoch: 30 | Review: 22194504/22511281 | Lr: 0.00704 | Smooth loss: 5.17029
# [INFO]  Epoch: 30 | Review: 22207304/22511281 | Lr: 0.00675 | Smooth loss: 5.17299
# [INFO]  Epoch: 30 | Review: 22220104/22511281 | Lr: 0.00647 | Smooth loss: 5.15372
# [INFO]  Epoch: 30 | Review: 22232904/22511281 | Lr: 0.00618 | Smooth loss: 5.09579
# [INFO]  Epoch: 30 | Review: 22245704/22511281 | Lr: 0.00590 | Smooth loss: 5.09891
# [INFO]  Epoch: 30 | Review: 22258504/22511281 | Lr: 0.00562 | Smooth loss: 5.04022
# [INFO]  Epoch: 30 | Review: 22271304/22511281 | Lr: 0.00533 | Smooth loss: 5.26850
# [INFO]  Epoch: 30 | Review: 22284104/22511281 | Lr: 0.00505 | Smooth loss: 5.14093
# [INFO]  Epoch: 30 | Review: 22296904/22511281 | Lr: 0.00476 | Smooth loss: 5.22849
# [INFO]  Epoch: 30 | Review: 22309704/22511281 | Lr: 0.00448 | Smooth loss: 5.08426
# [INFO]  Epoch: 30 | Review: 22322504/22511281 | Lr: 0.00419 | Smooth loss: 5.13229
# [INFO]  Epoch: 30 | Review: 22335304/22511281 | Lr: 0.00391 | Smooth loss: 5.13882
# [INFO]  Epoch: 30 | Review: 22348104/22511281 | Lr: 0.00363 | Smooth loss: 5.21825
# [INFO]  Epoch: 30 | Review: 22360904/22511281 | Lr: 0.00334 | Smooth loss: 5.03847
# [INFO]  Epoch: 30 | Review: 22373704/22511281 | Lr: 0.00306 | Smooth loss: 5.15615
# [INFO]  Epoch: 30 | Review: 22386504/22511281 | Lr: 0.00277 | Smooth loss: 5.09755
# [INFO]  Epoch: 30 | Review: 22399304/22511281 | Lr: 0.00249 | Smooth loss: 5.22272
# [INFO]  Epoch: 30 | Review: 22412104/22511281 | Lr: 0.00220 | Smooth loss: 5.21667
# [INFO]  Epoch: 30 | Review: 22424904/22511281 | Lr: 0.00192 | Smooth loss: 5.13088
# [INFO]  Epoch: 30 | Review: 22437704/22511281 | Lr: 0.00164 | Smooth loss: 5.09927
# [INFO]  Epoch: 30 | Review: 22450504/22511281 | Lr: 0.00135 | Smooth loss: 5.16347
# [INFO]  Epoch: 30 | Review: 22463304/22511281 | Lr: 0.00107 | Smooth loss: 5.15982
# [INFO]  Epoch: 30 | Review: 22476104/22511281 | Lr: 0.00078 | Smooth loss: 5.26914
# [INFO]  Epoch: 30 | Review: 22488904/22511281 | Lr: 0.00050 | Smooth loss: 5.08664
# [INFO]  Epoch: 30 | Review: 22501704/22511281 | Lr: 0.00021 | Smooth loss: 5.18943
# Load embeddings ../../data/ml1m/preprocessed/pgpr/tmp\train_transe_model/transe_model_sd_epoch_30.ckpt
# C:\Users\IT\OneDrive\Desktop\Projects\sem8_RS_project\models\PGPR\train_transe_model.py:62: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_file, map_location=lambda storage, loc: storage)

# %%
# Now going to learn the policy π. The goal is to find a policy that maximizes the cumulative reward
# %run train_agent --dataset {dataset_name}
# Out:
# [INFO]  Namespace(dataset='ml1m', name='train_agent', seed=123, gpu='0', epochs=50, batch_size=32, lr=0.0001, max_acts=250, max_path_len=3, gamma=0.99, ent_weight=0.001, act_dropout=0, state_history=1, hidden=[512, 256], device='cpu', log_dir='../../data/ml1m/preprocessed/pgpr/tmp\\train_agent')
# Load embedding: ../../data/ml1m/preprocessed/pgpr/tmp/transe_embed.pkl
# [INFO]  Parameters:['l1.weight', 'l1.bias', 'l2.weight', 'l2.bias', 'actor.weight', 'actor.bias', 'critic.weight', 'critic.bias']
# [INFO]  epoch/step=1/100 | loss=0.56705 | ploss=0.36920 | vloss=0.21244 | entropy=-14.60015 | reward=0.22313
# [INFO]  epoch/step=2/200 | loss=0.33977 | ploss=0.15067 | vloss=0.20368 | entropy=-14.58161 | reward=0.22005
# [INFO]  epoch/step=2/300 | loss=0.22393 | ploss=0.04188 | vloss=0.19661 | entropy=-14.56329 | reward=0.21802
# [INFO]  epoch/step=3/400 | loss=0.23307 | ploss=0.05366 | vloss=0.19404 | entropy=-14.62686 | reward=0.21858
# [INFO]  epoch/step=3/500 | loss=0.28138 | ploss=0.10770 | vloss=0.18829 | entropy=-14.61075 | reward=0.22234
# [INFO]  epoch/step=4/600 | loss=0.25205 | ploss=0.07704 | vloss=0.18954 | entropy=-14.53537 | reward=0.21899
# [INFO]  epoch/step=4/700 | loss=0.27112 | ploss=0.09595 | vloss=0.18975 | entropy=-14.57461 | reward=0.22281
# [INFO]  epoch/step=5/800 | loss=0.22982 | ploss=0.05441 | vloss=0.18998 | entropy=-14.56260 | reward=0.22637
# [INFO]  epoch/step=5/900 | loss=0.16941 | ploss=-0.00017 | vloss=0.18420 | entropy=-14.61154 | reward=0.21412
# [INFO]  epoch/step=6/1000 | loss=0.24959 | ploss=0.08186 | vloss=0.18233 | entropy=-14.59632 | reward=0.21320
# [INFO]  epoch/step=6/1100 | loss=0.19328 | ploss=0.02302 | vloss=0.18481 | entropy=-14.55589 | reward=0.21596
# [INFO]  epoch/step=7/1200 | loss=0.24154 | ploss=0.06960 | vloss=0.18649 | entropy=-14.54457 | reward=0.21817
# [INFO]  epoch/step=7/1300 | loss=0.22711 | ploss=0.05647 | vloss=0.18523 | entropy=-14.58000 | reward=0.22696
# [INFO]  epoch/step=8/1400 | loss=0.27442 | ploss=0.10515 | vloss=0.18390 | entropy=-14.62110 | reward=0.22109
# [INFO]  epoch/step=8/1500 | loss=0.20678 | ploss=0.03608 | vloss=0.18527 | entropy=-14.56925 | reward=0.22235
# [INFO]  epoch/step=9/1600 | loss=0.25587 | ploss=0.07843 | vloss=0.19207 | entropy=-14.62698 | reward=0.23041
# [INFO]  epoch/step=9/1700 | loss=0.21048 | ploss=0.04470 | vloss=0.18036 | entropy=-14.58825 | reward=0.22377
# [INFO]  epoch/step=10/1800 | loss=0.15948 | ploss=-0.01209 | vloss=0.18616 | entropy=-14.58411 | reward=0.22068
# [INFO]  Save models to ../../data/ml1m/preprocessed/pgpr/tmp\train_agent/policy_model_epoch_10.ckpt
# [INFO]  epoch/step=11/1900 | loss=0.20565 | ploss=0.03078 | vloss=0.18942 | entropy=-14.55910 | reward=0.22773
# [INFO]  epoch/step=11/2000 | loss=0.23690 | ploss=0.06657 | vloss=0.18492 | entropy=-14.59200 | reward=0.22301
# [INFO]  epoch/step=12/2100 | loss=0.19507 | ploss=0.02187 | vloss=0.18779 | entropy=-14.58494 | reward=0.22460
# [INFO]  epoch/step=12/2200 | loss=0.19493 | ploss=0.03647 | vloss=0.17302 | entropy=-14.55484 | reward=0.21803
# [INFO]  epoch/step=13/2300 | loss=0.22501 | ploss=0.05960 | vloss=0.18001 | entropy=-14.60163 | reward=0.22045
# [INFO]  epoch/step=13/2400 | loss=0.20189 | ploss=0.03774 | vloss=0.17872 | entropy=-14.56199 | reward=0.22178
# [INFO]  epoch/step=14/2500 | loss=0.18329 | ploss=0.01773 | vloss=0.18013 | entropy=-14.56314 | reward=0.22261
# [INFO]  epoch/step=14/2600 | loss=0.23324 | ploss=0.06916 | vloss=0.17862 | entropy=-14.54230 | reward=0.22024
# [INFO]  epoch/step=15/2700 | loss=0.20424 | ploss=0.03526 | vloss=0.18359 | entropy=-14.61188 | reward=0.23089
# [INFO]  epoch/step=15/2800 | loss=0.23620 | ploss=0.06977 | vloss=0.18098 | entropy=-14.55192 | reward=0.22606
# [INFO]  epoch/step=16/2900 | loss=0.16832 | ploss=0.00292 | vloss=0.18001 | entropy=-14.60804 | reward=0.22398
# [INFO]  epoch/step=16/3000 | loss=0.22050 | ploss=0.05719 | vloss=0.17787 | entropy=-14.56552 | reward=0.22365
# [INFO]  epoch/step=17/3100 | loss=0.18384 | ploss=0.01908 | vloss=0.17933 | entropy=-14.56218 | reward=0.22432
# [INFO]  epoch/step=17/3200 | loss=0.19420 | ploss=0.02854 | vloss=0.18027 | entropy=-14.61224 | reward=0.22487
# [INFO]  epoch/step=18/3300 | loss=0.20449 | ploss=0.03485 | vloss=0.18417 | entropy=-14.53217 | reward=0.22293
# [INFO]  epoch/step=18/3400 | loss=0.22378 | ploss=0.05792 | vloss=0.18044 | entropy=-14.58168 | reward=0.22765
# [INFO]  epoch/step=19/3500 | loss=0.21406 | ploss=0.05120 | vloss=0.17744 | entropy=-14.57544 | reward=0.22254
# [INFO]  epoch/step=20/3600 | loss=0.26665 | ploss=0.09246 | vloss=0.18880 | entropy=-14.61065 | reward=0.23635
# [INFO]  epoch/step=20/3700 | loss=0.08490 | ploss=-0.07379 | vloss=0.17327 | entropy=-14.57084 | reward=0.22145
# [INFO]  Save models to ../../data/ml1m/preprocessed/pgpr/tmp\train_agent/policy_model_epoch_20.ckpt
# [INFO]  epoch/step=21/3800 | loss=0.22835 | ploss=0.06247 | vloss=0.18047 | entropy=-14.58678 | reward=0.23048
# [INFO]  epoch/step=21/3900 | loss=0.21708 | ploss=0.04794 | vloss=0.18373 | entropy=-14.59213 | reward=0.23238
# [INFO]  epoch/step=22/4000 | loss=0.17455 | ploss=0.00934 | vloss=0.17973 | entropy=-14.51789 | reward=0.22210
# [INFO]  epoch/step=22/4100 | loss=0.23229 | ploss=0.06993 | vloss=0.17696 | entropy=-14.60455 | reward=0.23214
# [INFO]  epoch/step=23/4200 | loss=0.23840 | ploss=0.06837 | vloss=0.18460 | entropy=-14.56973 | reward=0.23667
# [INFO]  epoch/step=23/4300 | loss=0.18712 | ploss=0.02050 | vloss=0.18120 | entropy=-14.58704 | reward=0.23212
# [INFO]  epoch/step=24/4400 | loss=0.22045 | ploss=0.04941 | vloss=0.18561 | entropy=-14.58067 | reward=0.23279
# [INFO]  epoch/step=24/4500 | loss=0.13205 | ploss=-0.03056 | vloss=0.17717 | entropy=-14.56129 | reward=0.22497
# [INFO]  epoch/step=25/4600 | loss=0.19742 | ploss=0.03797 | vloss=0.17403 | entropy=-14.58115 | reward=0.22341
# [INFO]  epoch/step=25/4700 | loss=0.18924 | ploss=0.02520 | vloss=0.17863 | entropy=-14.58832 | reward=0.23357
# [INFO]  epoch/step=26/4800 | loss=0.20038 | ploss=0.03532 | vloss=0.17963 | entropy=-14.57350 | reward=0.22637
# [INFO]  epoch/step=26/4900 | loss=0.12917 | ploss=-0.03662 | vloss=0.18035 | entropy=-14.55566 | reward=0.22442
# [INFO]  epoch/step=27/5000 | loss=0.26864 | ploss=0.10172 | vloss=0.18148 | entropy=-14.56499 | reward=0.22796
# [INFO]  epoch/step=27/5100 | loss=0.16498 | ploss=-0.00067 | vloss=0.18022 | entropy=-14.56930 | reward=0.22941
# [INFO]  epoch/step=28/5200 | loss=0.21436 | ploss=0.04435 | vloss=0.18459 | entropy=-14.57719 | reward=0.23473
# [INFO]  epoch/step=29/5300 | loss=0.17310 | ploss=0.00925 | vloss=0.17840 | entropy=-14.55282 | reward=0.22833
# [INFO]  epoch/step=29/5400 | loss=0.21193 | ploss=0.04687 | vloss=0.17960 | entropy=-14.54419 | reward=0.22745
# [INFO]  epoch/step=30/5500 | loss=0.15729 | ploss=-0.00197 | vloss=0.17382 | entropy=-14.56026 | reward=0.22410
# [INFO]  epoch/step=30/5600 | loss=0.22688 | ploss=0.06326 | vloss=0.17816 | entropy=-14.54183 | reward=0.22116
# [INFO]  Save models to ../../data/ml1m/preprocessed/pgpr/tmp\train_agent/policy_model_epoch_30.ckpt
# [INFO]  epoch/step=31/5700 | loss=0.23628 | ploss=0.07069 | vloss=0.18019 | entropy=-14.59605 | reward=0.23554
# [INFO]  epoch/step=31/5800 | loss=0.15795 | ploss=-0.00712 | vloss=0.17964 | entropy=-14.58300 | reward=0.22604
# [INFO]  epoch/step=32/5900 | loss=0.21932 | ploss=0.05662 | vloss=0.17727 | entropy=-14.56689 | reward=0.22722
# [INFO]  epoch/step=32/6000 | loss=0.19146 | ploss=0.03335 | vloss=0.17266 | entropy=-14.54288 | reward=0.22678
# [INFO]  epoch/step=33/6100 | loss=0.15140 | ploss=-0.02073 | vloss=0.18670 | entropy=-14.57493 | reward=0.23343
# [INFO]  epoch/step=33/6200 | loss=0.18481 | ploss=0.02210 | vloss=0.17726 | entropy=-14.55290 | reward=0.22393
# [INFO]  epoch/step=34/6300 | loss=0.21943 | ploss=0.05286 | vloss=0.18113 | entropy=-14.57034 | reward=0.23002
# [INFO]  epoch/step=34/6400 | loss=0.19536 | ploss=0.02808 | vloss=0.18183 | entropy=-14.55088 | reward=0.23335
# [INFO]  epoch/step=35/6500 | loss=0.18395 | ploss=0.01595 | vloss=0.18259 | entropy=-14.58696 | reward=0.23273
# [INFO]  epoch/step=35/6600 | loss=0.14018 | ploss=-0.02175 | vloss=0.17646 | entropy=-14.53762 | reward=0.22837
# [INFO]  epoch/step=36/6700 | loss=0.16049 | ploss=-0.00609 | vloss=0.18112 | entropy=-14.53762 | reward=0.22388
# [INFO]  epoch/step=36/6800 | loss=0.24608 | ploss=0.08315 | vloss=0.17749 | entropy=-14.55464 | reward=0.22986
# [INFO]  epoch/step=37/6900 | loss=0.17903 | ploss=0.00874 | vloss=0.18480 | entropy=-14.50935 | reward=0.23217
# [INFO]  epoch/step=38/7000 | loss=0.24829 | ploss=0.08188 | vloss=0.18101 | entropy=-14.60006 | reward=0.23617
# [INFO]  epoch/step=38/7100 | loss=0.04711 | ploss=-0.10965 | vloss=0.17129 | entropy=-14.52535 | reward=0.22068
# [INFO]  epoch/step=39/7200 | loss=0.27945 | ploss=0.11219 | vloss=0.18183 | entropy=-14.56780 | reward=0.23506
# [INFO]  epoch/step=39/7300 | loss=0.10587 | ploss=-0.05446 | vloss=0.17489 | entropy=-14.55256 | reward=0.22710
# [INFO]  epoch/step=40/7400 | loss=0.17948 | ploss=0.01891 | vloss=0.17511 | entropy=-14.54300 | reward=0.22664
# [INFO]  epoch/step=40/7500 | loss=0.21712 | ploss=0.04772 | vloss=0.18396 | entropy=-14.56352 | reward=0.22948
# [INFO]  Save models to ../../data/ml1m/preprocessed/pgpr/tmp\train_agent/policy_model_epoch_40.ckpt
# [INFO]  epoch/step=41/7600 | loss=0.24115 | ploss=0.07359 | vloss=0.18213 | entropy=-14.56654 | reward=0.23038
# [INFO]  epoch/step=41/7700 | loss=0.23552 | ploss=0.06665 | vloss=0.18337 | entropy=-14.50237 | reward=0.23259
# [INFO]  epoch/step=42/7800 | loss=0.08812 | ploss=-0.07205 | vloss=0.17476 | entropy=-14.58161 | reward=0.22275
# [INFO]  epoch/step=42/7900 | loss=0.24133 | ploss=0.07453 | vloss=0.18138 | entropy=-14.57739 | reward=0.23412
# [INFO]  epoch/step=43/8000 | loss=0.21055 | ploss=0.04343 | vloss=0.18165 | entropy=-14.52475 | reward=0.23325
# [INFO]  epoch/step=43/8100 | loss=0.05435 | ploss=-0.10730 | vloss=0.17619 | entropy=-14.54575 | reward=0.22152
# [INFO]  epoch/step=44/8200 | loss=0.28043 | ploss=0.11837 | vloss=0.17660 | entropy=-14.53832 | reward=0.22837
# [INFO]  epoch/step=44/8300 | loss=0.22082 | ploss=0.05579 | vloss=0.17957 | entropy=-14.53333 | reward=0.23380
# [INFO]  epoch/step=45/8400 | loss=0.12869 | ploss=-0.03216 | vloss=0.17545 | entropy=-14.59657 | reward=0.22469
# [INFO]  epoch/step=45/8500 | loss=0.13739 | ploss=-0.02195 | vloss=0.17388 | entropy=-14.54404 | reward=0.22285
# [INFO]  epoch/step=46/8600 | loss=0.28849 | ploss=0.12485 | vloss=0.17816 | entropy=-14.52239 | reward=0.23094
# [INFO]  epoch/step=47/8700 | loss=0.22515 | ploss=0.05959 | vloss=0.18014 | entropy=-14.57074 | reward=0.22907
# [INFO]  epoch/step=47/8800 | loss=0.15587 | ploss=-0.00133 | vloss=0.17175 | entropy=-14.55868 | reward=0.22786
# [INFO]  epoch/step=48/8900 | loss=0.16416 | ploss=0.00247 | vloss=0.17624 | entropy=-14.54923 | reward=0.22634
# [INFO]  epoch/step=48/9000 | loss=0.25044 | ploss=0.08204 | vloss=0.18296 | entropy=-14.56594 | reward=0.23250
# [INFO]  epoch/step=49/9100 | loss=0.26056 | ploss=0.09025 | vloss=0.18485 | entropy=-14.53237 | reward=0.23475
# [INFO]  epoch/step=49/9200 | loss=0.15550 | ploss=-0.00956 | vloss=0.17961 | entropy=-14.55762 | reward=0.22775
# [INFO]  epoch/step=50/9300 | loss=0.04615 | ploss=-0.10971 | vloss=0.17039 | entropy=-14.53100 | reward=0.22083
# [INFO]  epoch/step=50/9400 | loss=0.31753 | ploss=0.14381 | vloss=0.18826 | entropy=-14.53997 | reward=0.23877
# [INFO]  Save models to ../../data/ml1m/preprocessed/pgpr/tmp\train_agent/policy_model_epoch_50.ckpt

# %%
# only remaining step is to extract the paths from the previously learned policy  π .
# This is done by executing a beam search using as score for every step the probability  π(at|st,Au,t) .
# %run test_agent --dataset {dataset_name}
# Out:
# Predicting paths...
# Load embedding: ../../data/ml1m/preprocessed/pgpr/tmp/transe_embed.pkl
# C:\Users\IT\OneDrive\Desktop\Projects\sem8_RS_project\models\PGPR\test_agent.py:168: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrain_sd = torch.load(policy_file)
# 6048it [1:30:33,  1.11it/s]

# %%
# %run test_agent --dataset {dataset_name} --run_path False --run_eval True
# Out:
# Load embedding: ../../data/ml1m/preprocessed/pgpr/tmp/transe_embed.pkl
# Normalizing items scores...
# Saving pred_paths...
# Average test set size:  31.553973509933776
# Overall for noOfUser=6040, ndcg=0.2987
#
#
# Overall for noOfUser=6040, hr=0.5358
#
#
# Overall for noOfUser=6040, precision=0.1004
#
#
# Overall for noOfUser=6040, recall=0.0473

# %% [markdown]
# ## Textual explanation creation and evaluation

# %%
import numpy as np
import pandas as pd
from random import seed, randint, choice
from collections import defaultdict
import pickle

dataset_name='ml1m'
models=['pgpr']
users_topk={model: defaultdict(list) for model in models}
train_labels={}
test_labels={}
# EVALUATION METRICS: alculate Normalized Discounted Cumulative Gain (NDCG), Recall and Precision.
ndcgs={model:[] for model in models}
recalls={model:[] for model in models}
precisions={model:[] for model in models}

# %%
def dcg_at_k(topk, k, method=1):
    topk=np.asarray(topk, dtype=float)[:k]
    if topk.size:
        if method==0:
            return topk[0]+np.sum(topk[1:] / np.log2(np.arange(2, topk.size+1)))
        elif method == 1:
            return np.sum(topk / np.log2(np.arange(2, topk.size+2)))
        else:
            raise ValueError('method must be 0 or 1.')
    return 0.

def ndcg_at_k(topk, k, method=1):
    dcg_max = dcg_at_k(sorted(topk, reverse=True), k, method)
    if not dcg_max:
        return 0.
    return dcg_at_k(topk, k, method) / dcg_max

def recall_at_k(topk, test_pids):
    return sum(topk) / len(test_pids)

def precision_at_k(topk, k):
    return sum(topk) / k

# %%
# To convert the explanations to plain text, we need to substitute the entities IDs with their name. To do that let's load these mappings for both models using the entity2plain_text function of the knowledge_graph_utils module.
from knowledge_graph_utils import entity2plain_text
entity2name = {}
entity2name["pgpr"] = entity2plain_text(dataset_name, "pgpr")

def path_len(path):
    len=0
    for s in path:
        if type(s) != str:
            s = str(s)
        if s.isnumeric():
            len+=1
    return len

# Path Structure: user 5038 watched product 2430 watched user 1498 watched product 1788
def template(curr_model, path):
    if path[0]=="self_loop":
        path=path[1:]
    path_length=path_len(path)
    for i in range(1, len(path)):
        s=str(path[i])
        if s.isnumeric():
            if path[i-1]=='user': 
                continue
            if int(path[i]) not in entity2name[curr_model][path[i-1]]: 
                continue
            path[i] = entity2name[curr_model][path[i-1]][int(path[i])]
    if path_length == 4:
        _, uid, rel_0, e_type_1, e_1, rel_1, e_type_2, e_2, rel_k, _, pid  = path
        return f"{pid} is recommend to you because you {rel_0} {e_1} also {rel_k} by {e_2}"
    elif path_len(path) == 3:
        _, uid, rel_0, e_type_1, e_1, rel_1, _, pid  = path
        return f"{pid} is recommend to you because is {rel_k} with {e_1} that you previously {rel_0}"
# Out:
# Opening file: data/ml1m/preprocessed/pgpr/mappings.txt.gz
# Header: ['product_0', 'Jumanji (1995)']
# Row 0: []
# Row 1: ['product_1', 'Grumpier Old Men (1995)']
# Row 2: []
# Row 3: ['product_2', 'Waiting to Exhale (1995)']
# Row 4: []
# Opening file: data/ml1m/preprocessed/pgpr/mappings.txt.gz
# Header: ['product_0', 'Jumanji (1995)']
# Row 0: []
# Row 1: ['product_1', 'Grumpier Old Men (1995)']
# Row 2: []
# Row 3: ['product_2', 'Waiting to Exhale (1995)']
# Row 4: []

# %%
curr_model="pgpr"

with open(f"results/{dataset_name}/{curr_model}/pred_paths.pkl", 'rb') as pred_paths_file:
    pred_paths_pgpr=pickle.load(pred_paths_file)
pred_paths_file.close()
pd.DataFrame(pred_paths_pgpr[:10], columns=["uid", "pid", "path_score", "path_probability", "path"])
# Out:
#    uid  pid          path_score  path_probability  \
# 0    0  584  0.5891642130483046          0.000004
# 1    0  584  0.5891642130483046          0.000002
# 2    0  584  0.5891642130483046          0.000005
# 3    0  584  0.5891642130483046          0.000002
# 4    0  584  0.5891642130483046          0.000002
# 5    0  584  0.5891642130483046          0.000002
# 6    0  584  0.5891642130483046          0.000002
# 7    0  584  0.5891642130483046          0.000002
# 8    0  584  0.5891642130483046          0.000001
# 9    0  584  0.5891642130483046          0.000002
#
#                                                 path
# 0  self_loop user 0 watched product 875 watched u...
# 1  self_loop user 0 watched product 875 watched u...
# 2  self_loop user 0 watched product 569 watched u...
# 3  self_loop user 0 watched product 760 watched u...
# 4  self_loop user 0 watched product 537 watched u...
# 5  self_loop user 0 watched product 2157 watched ...
# 6  self_loop user 0 watched product 499 watched u...
# 7  self_loop user 0 watched product 679 watched u...
# 8  self_loop user 0 watched product 2402 watched ...
# 9  self_loop user 0 watched product 1514 watched ...

# %%
header = ["uid", "pid", "path_score", "path_prob", "path"]
pred_paths_map_pgpr = defaultdict(dict)
for record in pred_paths_pgpr:
    uid, pid, path_score, path_prob, path = record
    if pid not in pred_paths_map_pgpr[uid]:
        pred_paths_map_pgpr[uid][pid] = []
    pred_paths_map_pgpr[uid][pid].append((float(path_score), float(path_prob), path))

n_users = len(pred_paths_map_pgpr.keys())
random_user = randint(0, n_users)
random_product = choice(list(pred_paths_map_pgpr[random_user].keys()))
print(pred_paths_map_pgpr[random_user][random_product])
# Out:
# [(0.7232408397882328, 1.3698380598725635e-06, 'self_loop user 766 watched product 671 watched user 3407 watched product 683'), (0.7232408397882328, 1.018620423565153e-06, 'self_loop user 766 watched product 671 watched user 4793 watched product 683'), (0.7232408397882328, 8.111001648103411e-07, 'self_loop user 766 watched product 953 watched user 3209 watched product 683'), (0.7232408397882328, 2.8296349228185136e-06, 'self_loop user 766 watched product 497 watched user 1486 watched product 683'), (0.7232408397882328, 3.8145597613947757e-07, 'self_loop user 766 watched product 118 watched user 1421 watched product 683'), (0.7232408397882328, 1.4622210073866881e-06, 'self_loop user 766 watched product 674 watched user 1372 watched product 683')]

# %%
# %cd models/PGPR
# Out:
# c:\Users\IT\OneDrive\Desktop\Projects\sem8_RS_project\models\PGPR

# %%
from pgpr_utils import load_labels

train_labels[curr_model] = load_labels(dataset_name, 'train')
test_labels[curr_model] = load_labels(dataset_name, 'test')

# %cd ../..
# Out:
# c:\Users\IT\OneDrive\Desktop\Projects\sem8_RS_project

# %%
best_pred_paths = {}
for uid in pred_paths_map_pgpr:
    if uid in train_labels[curr_model]:
        train_pids = set(train_labels[curr_model][uid])
    else:
        print("Invalid train_pids")
    best_pred_paths[uid] = []
    for pid in pred_paths_map_pgpr[uid]:
        if pid in train_pids:
            continue
        # Get the path with highest probability
        sorted_path = sorted(pred_paths_map_pgpr[uid][pid], key=lambda x: x[1], reverse=True)
        best_pred_paths[uid].append(sorted_path[0])

random_user = randint(0, n_users)
print(best_pred_paths[random_user][:5])

n=10
for uid in range(len(best_pred_paths.keys())):
    sorted_paths = sorted(best_pred_paths[uid], key=lambda x: (x[0], x[1]), reverse=True)
    sorted_paths = [[path[0], path[1], path[-1].split(" ")] for path in sorted_paths]
    topk_products = [int(path[-1][-1]) for path in sorted_paths[:n]]
    topk_explanations = [path[-1] for path in sorted_paths[:n]]
    users_topk[curr_model][uid] = list(zip(topk_products, topk_explanations))

random_user = randint(0, n_users)
users_topk[curr_model][random_user][0]
# Out:
# [(0.4039733102461305, 1.4403590284928214e-06, 'self_loop user 293 watched product 1225 related_to wikipage 7209 related_to product 1241'), (0.4551168962339, 4.050557890877826e-06, 'self_loop user 293 watched product 1225 related_to wikipage 709 related_to product 21'), (0.5104558979026127, 9.069613042811397e-06, 'self_loop user 293 watched product 1225 belong_to category 1759 belong_to product 2495'), (0.2740205975655808, 4.073062154930085e-05, 'self_loop user 293 watched product 1225 related_to wikipage 3560 related_to product 1258'), (0.5359952611805613, 1.2168482044216944e-06, 'self_loop user 293 watched product 1225 related_to wikipage 9608 related_to product 2835')]
# (1377,
#  ['self_loop',
#   'user',
#   '1283',
#   'watched',
#   'product',
#   '498',
#   'watched',
#   'user',
#   '3376',
#   'watched',
#   'product',
#   '1377'])

# %%
# Evaluation
# We use the hits array to calculate the utility metrics for that user.
# We repeat this process for every user and we store the metric values. At the end, we use them to compute the average values for the dataset.

for uid, rec_exp_tuples in users_topk[curr_model].items():
    hits = []
    for rec_exp_tuple in rec_exp_tuples:
        recommended_pid = rec_exp_tuple[0]
        if recommended_pid in test_labels[curr_model][uid]:
            hits.append(1)
        else:
            hits.append(0)
    while len(hits) < 10:
        hits.append(0)
    ndcg = ndcg_at_k(hits, n)
    precision = precision_at_k(hits, n)
    recall = recall_at_k(hits, test_labels[curr_model][uid])
    ndcgs[curr_model].append(ndcg)
    precisions[curr_model].append(precision)
    recalls[curr_model].append(recall)
print(f"Overall NDGC: {np.mean(ndcgs[curr_model])}, Precision: {np.mean(precisions[curr_model])}, Recall: {np.mean(recalls[curr_model])}")
# Out:
# Overall NDGC: 0.2987081828554165, Precision: 0.10038079470198677, Recall: 0.04730047882034777

# %%
# textual explanation generation
random_user = randint(0, len(users_topk[curr_model].keys()))
for i, pid_exp_tuple in enumerate(users_topk[curr_model][random_user]):
    pid, exp = pid_exp_tuple[0], pid_exp_tuple[1]
    users_topk[curr_model][random_user][i] = (pid, template(curr_model, exp))

pd.DataFrame(users_topk[curr_model][random_user], columns=["pid", "textual explanation"])
# Out:
#     pid                                textual explanation
# 0  2199  American Beauty (1999) is recommend to you bec...
# 1  1167  Men in Black (1997) is recommend to you becaus...
# 2   498  Silence of the Lambs is recommend to you becau...
# 3  1279  Titanic (1997) is recommend to you because you...
# 4   449  Schindler's List (1993) is recommend to you be...
# 5  2376  Sleepy Hollow (1999) is recommend to you becau...
# 6  2401  End of Days (1999) is recommend to you because...
# 7  2087  Haunting is recommend to you because you watch...
# 8   874  Star Wars: Episode V - The Empire Strikes Back...
# 9  1825  Shakespeare in Love (1998) is recommend to you...

# %% [markdown]
# # Conclusion
# **We investigated the dimension of reasoning path quality and how can we measure properties of reasonings path.<br>
# Since reasoning paths are the source that will be used to create the textual explanation, increasing the reasoning path quality (in terms of some properties) will consequently enchance the quality of the textual explanations.<br>
# We formalized three metrics to measure these perspective, in particular Linking Interaction Recency (LIR), Shared Entity Popularity (SEP) and Path Type Diversity (PTD).<br>
# We also showed how these metrics can be incorporated in the training process readapting the Multi-Hop scoring function and Reward fuction of PGPR.<br>
# The results showed that explanations produced by in-train model causes less side-effects in terms of (LID, SED and PTC), produce smaller decreases in NDCG and combining Post-Processing + In-train causes the best results in terms of both explanation path quality and recommendation utility.**
